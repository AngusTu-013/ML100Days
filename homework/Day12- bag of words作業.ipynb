# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
#print(dataset)
corpus=dataset['Review'].values
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
print(len(corpus), corpus)
# Out:
# 1000 ['Wow... Loved this place.' 'Crust is not good.'
#  'Not tasty and the texture was just nasty.'
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.'
#  'The selection on the menu was great and so were the prices.'
#  'Now I am getting angry and I want my damn pho.'
#  "Honeslty it didn't taste THAT fresh.)"
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.'
#  'The fries were great too.' 'A great touch.' 'Service was very prompt.'
#  'Would not go back.'
#  'The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.'
#  'I tried the Cape Cod ravoli, chicken, with cranberry...mmmm!'
#  'I was disgusted because I was pretty sure that was human hair.'
#  'I was shocked because no signs indicate cash only.'
#  'Highly recommended.' 'Waitress was a little slow in service.'
#  'This place is not worth your time, let alone Vegas.'
# ...

# %% [markdown]
# ### 從文本中取出所有單字

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)#'使用tokenize 技巧'
    for word in tokenized_sentence:
        whole_words.append(word)

# %%
len(whole_words), whole_words[20:]
# Out:
# (12676,
#  ['Stopped',
#   'by',
#   'during',
#   'the',
#   'late',
#   'May',
#   'bank',
#   'holiday',
#   'off',
#   'Rick',
#   'Steve',
#   'recommendation',
#   'and',
#   'loved',
#   'it',
#   '.',
#   'The',
#   'selection',
#   'on',
#   'the',
#   'menu',
#   'was',
#   'great',
#   'and',
#   'so',
#   'were',
#   'the',
#   'prices',
#   '.',
#   'Now',
#   'I',
#   'am',
#   'getting',
#   'angry',
#   'and',
#   'I',
#   'want',
#   'my',
#   'damn',
#   'pho',
#   '.',
#   'Honeslty',
#   'it',
#   'did',
#   "n't",
#   'taste',
#   'THAT',
#   'fresh',
#   '.',
#   ')',
#   'The',
#   'potatoes',
#   'were',
#   'like',
#   'rubber',
#   'and',
#   'you',
#   'could',
#   'tell',
#   'they',
#   'had',
#   'been',
#   'made',
#   'up',
#   'ahead',
#   'of',
#   'time',
#   'being',
#   'kept',
#   'under',
#   'a',
#   'warmer',
#   '.',
#   'The',
#   'fries',
#   'were',
#   'great',
#   'too',
#   '.',
#   'A',
#   'great',
#   'touch',
#   '.',
# ...

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    """自行填入"""
    word_index[word] = n 
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'latte': 0,
#  'enjoy': 1,
#  'bamboo': 2,
#  'downside': 3,
#  'EXPERIENCE': 4,
#  'Those': 5,
#  'yourself': 6,
#  'EVER': 7,
#  'pile': 8,
#  'shirt': 9,
#  'end': 10,
#  'entire': 11,
#  'discount': 12,
#  'Shrimp-': 13,
#  'LEGIT': 14,
#  'outdoor': 15,
#  'complaints': 16,
#  'offers': 17,
#  'TIME': 18,
#  'decent': 19,
#  'mesquite': 20,
#  'bit': 21,
#  'pepper..and': 22,
#  'hope': 23,
#  'Wienerschnitzel': 24,
#  'cocktail': 25,
#  'kid': 26,
#  'house': 27,
#  'heads': 28,
#  'so': 29,
#  'Also': 30,
#  'May': 31,
#  'Green': 32,
#  'law': 33,
#  'away': 34,
#  'Ryan': 35,
#  'received': 36,
#  'coziness': 37,
#  'Nargile': 38,
#  'patty': 39,
#  '12': 40,
#  'cocktails': 41,
#  'liking': 42,
#  'No': 43,
#  '--': 44,
#  'awkwardly': 45,
#  'winner': 46,
#  'whether': 47,
#  'lacking': 48,
#  'croutons': 49,
#  'Francisco': 50,
#  'hankering': 51,
#  'crisp': 52,
#  'thanks': 53,
#  'watched': 54,
#  'stepped': 55,
#  'box': 56,
#  'tragedy': 57,
#  'pumpkin': 58,
# ...

# %%
index_word
# Out:
# {0: 'latte',
#  1: 'enjoy',
#  2: 'bamboo',
#  3: 'downside',
#  4: 'EXPERIENCE',
#  5: 'Those',
#  6: 'yourself',
#  7: 'EVER',
#  8: 'pile',
#  9: 'shirt',
#  10: 'end',
#  11: 'entire',
#  12: 'discount',
#  13: 'Shrimp-',
#  14: 'LEGIT',
#  15: 'outdoor',
#  16: 'complaints',
#  17: 'offers',
#  18: 'TIME',
#  19: 'decent',
#  20: 'mesquite',
#  21: 'bit',
#  22: 'pepper..and',
#  23: 'hope',
#  24: 'Wienerschnitzel',
#  25: 'cocktail',
#  26: 'kid',
#  27: 'house',
#  28: 'heads',
#  29: 'so',
#  30: 'Also',
#  31: 'May',
#  32: 'Green',
#  33: 'law',
#  34: 'away',
#  35: 'Ryan',
#  36: 'received',
#  37: 'coziness',
#  38: 'Nargile',
#  39: 'patty',
#  40: '12',
#  41: 'cocktails',
#  42: 'liking',
#  43: 'No',
#  44: '--',
#  45: 'awkwardly',
#  46: 'winner',
#  47: 'whether',
#  48: 'lacking',
#  49: 'croutons',
#  50: 'Francisco',
#  51: 'hankering',
#  52: 'crisp',
#  53: 'thanks',
#  54: 'watched',
#  55: 'stepped',
#  56: 'box',
#  57: 'tragedy',
#  58: 'pumpkin',
# ...

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            '''自行填入'''
            vector[word_index[word]] += 1
            
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
v= _get_bag_of_words_vector('The Heart Attack Grill in downtown Vegas is an absolutely flat-lined excuse for a restaurant.', word_index, whole_words)
print(len(v), type(v))
# Out:
# 2356 <class 'numpy.ndarray'>

# %% [markdown]
# ==============

# %%
from sklearn.feature_extraction.text import CountVectorizer
#Creating bag of word model
#max_features是要建造幾個column，會按造字出現的高低去篩選，如果給1000代表出現頻率前1000個單字才會納入計算，其他會排除
cv=CountVectorizer(max_features=1000)
#toarray是建造matrixs
#X現在為sparsity就是很多零的matrix
X=cv.fit_transform(whole_words).toarray()
y=dataset.iloc[:,1].values

# %%
print('X shape : {}'.format(X.shape))
# Out:
# X shape : (2356, 1000)

# %%
cv.get_feature_names() ## 第一個單字對應到的index就是0，以此類推
# Out:
# ['00',
#  '10',
#  'after',
#  'again',
#  'all',
#  'also',
#  'although',
#  'always',
#  'ambience',
#  'an',
#  'and',
#  'any',
#  'appetizers',
#  'are',
#  'area',
#  'as',
#  'at',
#  'atmosphere',
#  'attack',
#  'avoid',
#  'awesome',
#  'awful',
#  'back',
#  'bacon',
#  'bad',
#  'bar',
#  'be',
#  'been',
#  'before',
#  'best',
#  'better',
#  'big',
#  'bland',
#  'both',
#  'boy',
#  'breakfast',
#  'buffet',
#  'bunch',
#  'burger',
#  'but',
#  'by',
#  'cant',
#  'check',
#  'chef',
#  'chicken',
#  'coffee',
#  'come',
#  'coming',
#  'company',
#  'cooked',
#  'could',
#  'crispy',
#  'crust',
#  'customer',
#  'cute',
#  'damn',
#  'definitely',
#  'delicious',
#  'delight',
#  'dessert',
#  'dirty',
#  'disappointed',
#  'disappointing',
#  'do',
#  'dog',
#  'down',
#  'drinks',
#  'each',
#  'eating',
#  'egg',
#  'eggplant',
#  'enough',
#  'establishment',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'experience',
#  'extremely',
# ...
