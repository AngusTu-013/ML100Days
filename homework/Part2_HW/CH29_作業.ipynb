# %% [markdown]
# # 作業 : 調整 Bert 模型的不同訓練參數

# %%
# Mount Google Drive to Colab
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pwd
# !ls -al
# %cd '/content/gdrive/My Drive/NLP/Part2/Day29_Bert/'
# !ls -al
# Out:
# /content
# total 20
# drwxr-xr-x 1 root root 4096 Jun  2 06:26 .
# drwxr-xr-x 1 root root 4096 Jun  2 06:25 ..
# drwxr-xr-x 4 root root 4096 May  6 13:43 .config
# drwx------ 5 root root 4096 Jun  2 06:26 gdrive
# drwxr-xr-x 1 root root 4096 May  6 13:44 sample_data
# /content/gdrive/My Drive/NLP/Part2/Day29_Bert
# total 123
# -rw------- 1 root root  9727 Jun  2 06:26 CH29_作業.ipynb
# -rw------- 1 root root 76487 Jun  2 06:25 CH29_範例.ipynb
# -rw------- 1 root root  5559 May 31 02:38 GPT.py
# drwx------ 2 root root  4096 Jun  2 05:51 MRPC
# drwx------ 2 root root  4096 Jun  2 05:51 __pycache__
# -rw------- 1 root root 11544 May 31 02:38 transformer.py
# -rw------- 1 root root  9501 May 31 02:38 utils.py
# drwx------ 2 root root  4096 Jun  2 06:24 visual

# %% [markdown]
# # [作業目標]
# - 調整 Bert 模型的不同參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [作業重點]
# - 調整 Bert 模型的不同訓練參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [參數說明]
# - MODEL_DIM : Attention 特徵維度，即每一筆訓練輸入單字的個數
# - N_LAYER : Attention 堆疊的層數
# - LEARNING_RATE : 學習速率，影響收斂的快慢
# - MASK_RATE : 掩碼比例(介於 0 到 0.5 間, 建議值 0.15)

# %% [markdown]
# # 程式說明
# - 程式採用 tensorflow2 / keras 寫作, 執行前請先安裝 tensorflow 2.0
# - 本程式執行時, 請將 utils.py / transformer.py / GPT.py 等三個檔案與執行檔放置於同一目錄下
# - 程式來源 : 莫煩Python-BERT:雙向語言模型 https://mofanpy.com/tutorials/machine-learning/nlp/bert/

# %%
# [BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding](https://arxiv.org/pdf/1810.04805.pdf)
import numpy as np
import tensorflow as tf
import utils    # this refers to utils.py in my [repo](https://github.com/MorvanZhou/NLP-Tutorials/)
import time
from GPT import GPT
import os
import pickle


class BERT(GPT):
    def __init__(self, model_dim, max_len, n_layer, n_head, n_vocab, lr, max_seg=3, drop_rate=0.1, padding_idx=0):
        super().__init__(model_dim, max_len, n_layer, n_head, n_vocab, lr, max_seg, drop_rate, padding_idx)
        # I think task emb is not necessary for pretraining,
        # because the aim of all tasks is to train a universal sentence embedding
        # the body encoder is the same across all tasks,
        # and different output layer defines different task just like transfer learning.
        # finetuning replaces output layer and leaves the body encoder unchanged.

        # self.task_emb = keras.layers.Embedding(
        #     input_dim=n_task, output_dim=model_dim,  # [n_task, dim]
        #     embeddings_initializer=tf.initializers.RandomNormal(0., 0.01),
        # )

    def step(self, seqs, segs, seqs_, loss_mask, nsp_labels):
        with tf.GradientTape() as tape:
            mlm_logits, nsp_logits = self.call(seqs, segs, training=True)
            mlm_loss_batch = tf.boolean_mask(self.cross_entropy(seqs_, mlm_logits), loss_mask)
            mlm_loss = tf.reduce_mean(mlm_loss_batch)
            nsp_loss = tf.reduce_mean(self.cross_entropy(nsp_labels, nsp_logits))
            loss = mlm_loss + 0.2 * nsp_loss
            grads = tape.gradient(loss, self.trainable_variables)
            self.opt.apply_gradients(zip(grads, self.trainable_variables))
        return loss, mlm_logits

    def mask(self, seqs):
        mask = tf.cast(tf.math.equal(seqs, self.padding_idx), tf.float32)
        return mask[:, tf.newaxis, tf.newaxis, :]  # [n, 1, 1, step]


def _get_loss_mask(len_arange, seq, pad_id):
    rand_id = np.random.choice(len_arange, size=max(2, int(MASK_RATE * len(len_arange))), replace=False)
    loss_mask = np.full_like(seq, pad_id, dtype=np.bool)
    loss_mask[rand_id] = True
    return loss_mask[None, :], rand_id


def do_mask(seq, len_arange, pad_id, mask_id):
    loss_mask, rand_id = _get_loss_mask(len_arange, seq, pad_id)
    seq[rand_id] = mask_id
    return loss_mask


def do_replace(seq, len_arange, pad_id, word_ids):
    loss_mask, rand_id = _get_loss_mask(len_arange, seq, pad_id)
    seq[rand_id] = np.random.choice(word_ids, size=len(rand_id))
    return loss_mask


def do_nothing(seq, len_arange, pad_id):
    loss_mask, _ = _get_loss_mask(len_arange, seq, pad_id)
    return loss_mask


def random_mask_or_replace(data, arange, batch_size):
    seqs, segs, xlen, nsp_labels = data.sample(batch_size)
    seqs_ = seqs.copy()
    p = np.random.random()
    if p < 0.7:
        # mask
        loss_mask = np.concatenate(
            [do_mask(
                seqs[i],
                np.concatenate((arange[:xlen[i, 0]], arange[xlen[i, 0] + 1:xlen[i].sum() + 1])),
                data.pad_id,
                data.v2i["<MASK>"]) for i in range(len(seqs))], axis=0)
    elif p < 0.85:
        # do nothing
        loss_mask = np.concatenate(
            [do_nothing(
                seqs[i],
                np.concatenate((arange[:xlen[i, 0]], arange[xlen[i, 0] + 1:xlen[i].sum() + 1])),
                data.pad_id) for i in range(len(seqs))], axis=0)
    else:
        # replace
        loss_mask = np.concatenate(
            [do_replace(
                seqs[i],
                np.concatenate((arange[:xlen[i, 0]], arange[xlen[i, 0] + 1:xlen[i].sum() + 1])),
                data.pad_id,
                data.word_ids) for i in range(len(seqs))], axis=0)
    return seqs, segs, seqs_, loss_mask, xlen, nsp_labels


def train(model, data, step=10000, name="bert"):
    t0 = time.time()
    arange = np.arange(0, data.max_len)
    for t in range(step):
        seqs, segs, seqs_, loss_mask, xlen, nsp_labels = random_mask_or_replace(data, arange, 16)
        loss, pred = model.step(seqs, segs, seqs_, loss_mask, nsp_labels)
        if t % 100 == 0:
            pred = pred[0].numpy().argmax(axis=1)
            t1 = time.time()
            print(
                "\n\nstep: ", t,
                "| time: %.2f" % (t1 - t0),
                "| loss: %.3f" % loss.numpy(),
                "\n| tgt: ", " ".join([data.i2v[i] for i in seqs[0][:xlen[0].sum()+1]]),
                "\n| prd: ", " ".join([data.i2v[i] for i in pred[:xlen[0].sum()+1]]),
                "\n| tgt word: ", [data.i2v[i] for i in seqs_[0]*loss_mask[0] if i != data.v2i["<PAD>"]],
                "\n| prd word: ", [data.i2v[i] for i in pred*loss_mask[0] if i != data.v2i["<PAD>"]],
                )
            t0 = t1
    os.makedirs("./visual/models/%s" % name, exist_ok=True)
    model.save_weights("./visual/models/%s/model.ckpt" % name)


def export_attention(model, data, name="bert"):
    model.load_weights("./visual/models/%s/model.ckpt" % name)

    # save attention matrix for visualization
    seqs, segs, xlen, nsp_labels = data.sample(32)
    model.call(seqs, segs, False)
    data = {"src": [[data.i2v[i] for i in seqs[j]] for j in range(len(seqs))], "attentions": model.attentions}
    path = "./visual/tmp/%s_attention_matrix.pkl" % name
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, "wb") as f:
        pickle.dump(data, f)


if __name__ == "__main__":
    utils.set_soft_gpu(True)
    MODEL_DIM = 256
    N_LAYER = 5
    LEARNING_RATE = 1e-4
    MASK_RATE = 0.15

    d = utils.MRPCData("./MRPC", 2000)
    print("num word: ", d.num_word)
    m = BERT(
        model_dim=MODEL_DIM, max_len=d.max_len, n_layer=N_LAYER, n_head=4, n_vocab=d.num_word,
        lr=LEARNING_RATE, max_seg=d.num_seg, drop_rate=0.2, padding_idx=d.v2i["<PAD>"])
    train(m, d, step=10000, name="bert")
    export_attention(m, d, "bert")
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# num word:  12880
#
#
# step:  0 | time: 0.37 | loss: 9.700
# | tgt:  <GO> identical wording was introduced in the senate last week by three republicans , wayne <MASK> ( colo . ) <MASK> jeff sessions ( ala . ) <MASK> sam brownback ( kan <MASK> ) . <SEP> identical wording was introduced in the senate <MASK> week <MASK> three republicans <MASK> wayne allard of colorado , jeff sessions <MASK> alabama <MASK> sam brownback of kansas
# | prd:  sales outback bedroom fact-finding wing outback additional peninsula flown sales chapter rounds <NUM>-feet-2 shelf invercargill relief victory scene superintendent peninsula benning relief florence-marie peninsula dillard fact-finding chapter year-earlier event fact-finding invercargill chapter peninsula takeoff relief treacherous fact-finding fertilizer sobriety fact-finding event mountains fact-finding fact-finding proves victory scene fished fact-finding biography confirmations bedroom evaluation fact-finding fished peninsula returned fact-finding fact-finding gormley evaluation florence-marie law-breaker
# | tgt word:  ['allard', ',', 'and', '.', 'last', 'by', ':', 'of', 'and']
# | prd word:  ['relief', 'benning', 'year-earlier', 'peninsula', 'fact-finding', 'victory', 'fact-finding', 'returned', 'fact-finding']
#
#
# step:  100 | time: 15.53 | loss: 7.652
# | tgt:  <GO> <quote> kmart needs to dramatically overhaul management in the areas of buying , store operations and sourcing , <quote> he said . <SEP> overall , <quote> kmart needs to dramatically overhaul management in the areas of buying , store operations and sourcing , <quote> said burt flickinger of strategic resource group
# | prd:  the the the the the the the the , the the , the the the the the the the the the the the the the the the the the the the , the the the the the the the the the the the the the the the the , the <NUM> the
# | tgt word:  ['in', 'the', 'he', '<SEP>', '<quote>', ',', 'group']
# | prd word:  [',', 'the', 'the', 'the', 'the', 'the', 'the']
#
#
# step:  200 | time: 15.46 | loss: 6.929
# | tgt:  <GO> <quote> i think it 's going to be a close vote , but i think the grant <MASK> is <MASK> to win , <quote> mcconnell said . <SEP> <quote> <MASK> think it 's <MASK> to be <MASK> close vote , <MASK> i think the grant <MASK> 's going to win , <quote> said sen. mitch mcconnell , <MASK> <MASK> leader
# | prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# | tgt word:  ['proposal', 'going', 'i', 'going', 'a', 'but', 'proposal', 'assistant', 'majority']
# | prd word:  ['the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the']
#
#
# step:  300 | time: 15.51 | loss: 6.931
# | tgt:  <GO> he served as a marine in the second <MASK> war and afterward began submitting articles to magazines . <MASK> after <MASK> as a marine in world war <MASK> , he began submitting articles <MASK> magazines
# | prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# | tgt word:  ['world', '<SEP>', 'serving', 'ii', 'to']
# | prd word:  ['the', 'the', 'the', 'the', 'the']
#
#
# step:  400 | time: 15.48 | loss: 6.936
# | tgt:  <GO> <MASK> the accusation that i misappropriated money from jennifer lopez is both untrue and <MASK> <MASK> <quote> medina said in a statement . <SEP> <MASK> response , medina issued the <MASK> statement : <quote> the accusation that i misappropriated money from jennifer lopez <MASK> <MASK> untrue and offensive
# | prd:  <GO> the the , the , the the , the , , , , the , the the , , the , the , , , , , , , , , , , , the , , , , , , , , , , , , ,
# | tgt word:  ['<quote>', 'offensive', ',', 'in', 'following', 'is', 'both']
# | prd word:  ['the', ',', 'the', ',', ',', ',', ',']
#
#
# step:  500 | time: 15.57 | loss: 6.934
# | tgt:  <GO> cambone said u.s forces found the tractor-trailer april <NUM> at a kurdish checkpoint near the city of mosul in <MASK> iraq . <SEP> kurdish forces <MASK> a <MASK> near <MASK> in northern iraq seized the trailer on <MASK> <NUM>
# | prd:  <GO> <NUM> <NUM> <NUM> <NUM> <NUM> the <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> the <NUM> <GO> <NUM> <GO> <NUM> <GO> <NUM> <GO> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> the <NUM> <NUM> <NUM> <NUM>
# | tgt word:  ['northern', 'at', 'checkpoint', 'mosul', 'april']
# | prd word:  ['<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>']
#
#
# step:  600 | time: 15.42 | loss: 6.755
# | tgt:  <GO> before addressing the economy , bush discussed the terrorist attacks in <MASK> arabia , which killed <MASK> many as <NUM> people , including <MASK> <MASK> . <SEP> the president began his <MASK> by acknowledging the terrorist attacks in saudi arabia that killed at least <NUM> people <MASK> <MASK> seven americans
# | prd:  <GO> the the the the , the the the the the the the the , the the the <SEP> <SEP> the the , the the <SEP> the <SEP> the the the the the the the the the the the the the the the the the the the the the the the
# | tgt word:  ['saudi', 'as', 'seven', 'americans', 'speech', ',', 'including']
# | prd word:  ['the', 'the', 'the', '<SEP>', 'the', 'the', 'the']
#
#
# step:  700 | time: 15.46 | loss: 6.694
# | tgt:  <GO> blacks mr candidate receiving have suisse entitled to these superannuation payments irrespective of ... ( how ) he left the company , <quote> mr argus said . site <quote> mr gilbertson would have promptly entitled to these ( pension no payments irrespective of the circumstances in which he left the company , <quote> mr argus endanger
# | prd:  <GO> the the the , the , , , the the the , the the , <SEP> <SEP> <SEP> the the <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> the the the the the , the , the , , the , , the the the the the the the the , , the the the the
# | tgt word:  ['<quote>', 'gilbertson', 'would', 'been', '<SEP>', 'been', ')', 'said']
# | prd word:  ['the', 'the', ',', ',', '<SEP>', ',', 'the', 'the']
#
#
# step:  800 | time: 15.49 | loss: 6.301
# | tgt:  <GO> he is accused of obstructing justice , witness <MASK> and destroying evidence . <SEP> quattrone <MASK> <NUM> <MASK> is charged with obstruction of justice <MASK> witness tampering
# | prd:  <GO> the the the , <NUM> the , , , the , , , <SEP> , , <NUM> the , , the , the , , , the
# | tgt word:  ['tampering', ',', ',', 'and']
# | prd word:  [',', ',', 'the', ',']
#
#
# step:  900 | time: 15.47 | loss: 6.482
# | tgt:  <GO> spot <MASK> was <MASK> at $ <MASK> / <NUM> an ounce at <MASK> gmt , having marched up to $ <NUM> -- a level not seen since <MASK> <NUM> . <SEP> spot gold was quoted at $ <NUM> / <NUM> an ounce at <MASK> gmt , having darted as <MASK> as $ <MASK> -- a level not <MASK> since february <NUM>
# | prd:  <GO> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> , <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <SEP> <NUM> <NUM> <NUM> <SEP> <NUM> <NUM> <GO> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> , <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM>
# | tgt word:  ['gold', 'quoted', '<NUM>', '<NUM>', 'february', '<NUM>', 'high', '<NUM>', 'seen']
# | prd word:  ['<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>']
#
#
# step:  1000 | time: 15.36 | loss: 6.415
# | tgt:  <GO> <MASK> authorities blame al qaeda for the attacks , <MASK> killed <NUM> people , including <NUM> americans . <SEP> u.s. authorities blame osama <MASK> laden <MASK> al-qaida network for the attacks <MASK> which killed <NUM> people <MASK> including <NUM> americans
# | prd:  <GO> the , , , , the the the , , , <NUM> the , , <NUM> , the <SEP> the , , the , the , the , the the the , the , <NUM> , , , <NUM> ,
# | tgt word:  ['us', 'which', 'bin', "'s", ',', ',']
# | prd word:  ['the', ',', ',', ',', ',', ',']
#
#
# step:  1100 | time: 15.51 | loss: 5.792
# | tgt:  <GO> shares of usa interactive rose $ <MASK> , or <NUM> percent , to $ <MASK> on friday in nasdaq stock market composite trading and have gained <NUM> percent this year . <SEP> shares of lendingtree <MASK> $ <NUM> <MASK> or <NUM> <MASK> , to close at $ <NUM> on the <MASK> <MASK> market <MASK>
# | prd:  <GO> the <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> , <NUM> <NUM> <NUM> , to <NUM> <NUM> <NUM> <NUM> <SEP> <NUM> <NUM> <NUM> <NUM> <NUM> the <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <SEP> <SEP> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> , <NUM> <NUM> <NUM> <NUM> <NUM> <NUM> the <NUM> <NUM> <NUM> <NUM>
# | tgt word:  ['<NUM>', '<NUM>', 'rose', ',', 'percent', 'nasdaq', 'stock', 'yesterday']
# | prd word:  ['<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>']
#
#
# step:  1200 | time: 15.50 | loss: 5.902
# | tgt:  <GO> also tuesday , the united states also released more iraqi prisoners of war , and officials announced that all would soon be let go . <SEP> meanwhile in southern iraq , the united states released more iraqi prisoners of war , and officials announced that all would be let go soon
# | prd:  <GO> the the , the , the , and the the , of , , and the , , , and the to the and <SEP> <SEP> , <SEP> and of , the , , and , the , of , , and , , , , , , and , and
# | tgt word:  ['let', 'southern', 'united', 'prisoners', 'officials', 'be', 'go']
# | prd word:  ['the', 'and', ',', ',', ',', ',', ',']
#
#
# step:  1300 | time: 15.73 | loss: 6.467
# | tgt:  <GO> <MASK> <NUM> u.s. <MASK> remain <MASK> iraq , <MASK> others deployed in afghanistan , south korea and elsewhere . <SEP> about <NUM> us soldiers remain in iraq , with others serving in afghanistan , south korea <MASK> japan <MASK> germany and elsewhere
# | prd:  <GO> the <NUM> the , , , , , , , <NUM> in the , <NUM> , and <SEP> the <SEP> <NUM> <NUM> , , , in , , , , , in <NUM> , , , <NUM> , the <NUM> and in
# | tgt word:  ['about', 'troops', 'in', 'with', ',', ',']
# | prd word:  ['the', ',', ',', ',', '<NUM>', 'the']
#
#
# step:  1400 | time: 15.33 | loss: 6.610
# | tgt:  <GO> there were no <MASK> to build permanent us <MASK> in africa , pentagon officials said . <SEP> there are no plans to build permanent u.s. <MASK> in africa , defense department officials <MASK>
# | prd:  <GO> the and , , to , , , , in , , and and , , <SEP> , and , , , , , , , in , , , , , ,
# | tgt word:  ['plans', 'bases', 'bases', 'say']
# | prd word:  [',', ',', ',', ',']
#
#
# step:  1500 | time: 15.46 | loss: 6.531
# | tgt:  assailants <quote> raked likewise page coca-cola h. experience in managing some of the world 's largest and most familiar brands , <quote> heyer said in a quit . <SEP> discovery a statement , heyer said , <quote> dan brings to coca-cola enormous experience in managing some of the world 's stewart and most familiar brands
# | prd:  <GO> <quote> , the , of the , in and , of the a , of and the the of , <quote> the the in a , , <SEP> <quote> a said , a , , <quote> , and to and , and in , of of the a , said and , <quote> and
# | tgt word:  ['<GO>', 'dan', 'brings', 'to', 'enormous', 'statement', 'in', 'largest']
# | prd word:  ['<GO>', ',', 'the', ',', 'the', ',', '<quote>', 'said']
#
#
# step:  1600 | time: 15.49 | loss: 6.529
# | tgt:  <GO> the rats that consumed the tomato powder had <MASK> <NUM> percent lower risk <MASK> prostate <MASK> death than the control rats , researchers found . <SEP> rats on the <MASK> powder diet had a <NUM> percent <MASK> risk of prostate cancer <MASK> than the control <MASK> , allowing for diet restriction
# | prd:  <GO> the the , , the <NUM> <NUM> the <NUM> <NUM> <SEP> the the <NUM> <NUM> <NUM> , <NUM> the the <NUM> , <SEP> <NUM> the <SEP> , the the <NUM> <NUM> the the a <NUM> <NUM> <NUM> the of <NUM> the <NUM> <NUM> the the the , the the the the
# | tgt word:  ['a', 'of', 'cancer', 'tomato', 'lower', 'death', 'rats']
# | prd word:  ['<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', 'the']
#
#
# step:  1700 | time: 15.43 | loss: 6.926
# | tgt:  <GO> tony blair quinn taken a rejecting stance arguing nothing should be done to lessen the pressure on mugabe at the gathering in conclude capital abuja . <SEP> the prime widow has taken a t. stance arguing nothing should transit done to lessen the pressure on mugabe
# | prd:  <GO> the a the to a the to to to to to the to to the a the to to the the in the a to the <SEP> the a to the to a the to to to to to to to to the to the to
# | tgt word:  ['has', 'hardline', 'the', 'minister', 'hardline', 'be']
# | prd word:  ['the', 'the', 'the', 'to', 'the', 'to']
#
#
# step:  1800 | time: 15.41 | loss: 6.675
# | tgt:  <GO> <MASK> brabazon said his son <MASK> get upset but then turn <MASK> and befriend his taunters . <SEP> her son would get upset , his <MASK> said , but then turn around and befriend his <MASK>
# | prd:  <GO> the , the , , and , and and and and , and and and and <SEP> <SEP> and , and , and , , and , , and and and and and and and and
# | tgt word:  ['brian', 'would', 'around', 'mom', 'taunters']
# | prd word:  ['the', 'and', ',', 'and', 'and']
#
#
# step:  1900 | time: 15.28 | loss: 5.922
# | tgt:  <GO> his coalition also passed some of the world <MASK> most progressive laws in legalizing gay marriage and euthanasia and decriminalizing the personal use of soft drugs . <SEP> <MASK> <MASK> passed some of <MASK> <MASK> 's most progressive social legislation , legalising gay marriage and <MASK>
# | prd:  <GO> the of and , the of the and of the , and in of and and and <GO> and the the <SEP> and of and <SEP> <SEP> <SEP> the the and the of of and the of and and and , and the and and and
# | tgt word:  ["'s", 'the', 'coalition', 'the', 'world', 'euthanasia']
# | prd word:  ['of', 'the', 'the', 'of', 'and', 'and']
#
#
# step:  2000 | time: 15.63 | loss: 6.542
# | tgt:  <GO> several cities are competing for the headquarters , including miami ; <MASK> city ; <MASK> ; port-of-spain , <MASK> <MASK> and puebla , mexico . <SEP> but miami <MASK> competing <MASK> <MASK> other cities , including atlanta ; panama city ; port-of-spain , trinidad ; and cancn , mexico
# | prd:  <GO> the , , , , the , , , , , , , , , and and , , , and and , and <SEP> <SEP> , , , , , , , , , , , , , , , , , , , and , , and
# | tgt word:  ['panama', 'atlanta', 'trinidad', ';', 'is', 'with', 'eight']
# | prd word:  [',', ',', ',', ',', ',', ',', ',']
#
#
# step:  2100 | time: 15.35 | loss: 4.828
# | tgt:  <GO> the legislature on wednesday sent gov. jeb bush a bill it hopes will lower malpractice insurance rates and keep doctors from limiting their practices or moving out of state . <SEP> the legislature on wednesday approved a bill that caps damages received by medical malpractice plaintiffs in the hopes it will lower insurance rates and help the state retain doctors
# | prd:  <GO> the the the the the the the the a the the the of the the the the and the the the the the the , the the of the <SEP> <SEP> the the the the the a the to the the the the the the the in the the the the the the the and the the the the the
# | tgt word:  ['the', 'the', 'wednesday', 'that', 'received', 'malpractice', 'the', 'it', 'will']
# | prd word:  ['the', 'the', 'the', 'to', 'the', 'the', 'the', 'the', 'the']
#
#
# step:  2200 | time: 15.42 | loss: 5.894
# | tgt:  <GO> the <MASK> newspaper okaz reported monday <MASK> suspects who escaped saturday 's raid fled <MASK> <MASK> car that broke down on the outskirts of mecca sunday afternoon . <SEP> <MASK> newspaper okaz reported that the <MASK> suspects arrested sunday fled the raid in a car that broke down on <MASK> outskirts of mecca
# | prd:  <GO> the the was a a a the a a the a 's the a the the the a the a the the the of in in a <SEP> <SEP> the the a a the the the the in the the the the in a the a a a the a a of in
# | tgt word:  ['saudi', 'that', 'in', 'a', 'the', 'six', 'the']
# | prd word:  ['the', 'the', 'the', 'the', 'the', 'the', 'a']
#
#
# step:  2300 | time: 15.43 | loss: 6.552
# | tgt:  <GO> the virus kills <MASK> <NUM> people <MASK> an average year <MASK> according to the u.s. centers for disease control and prevention . <SEP> complications from <MASK> kill roughly <NUM> americans in an average year , according to <MASK> u.s. <MASK> for disease control and prevention
# | prd:  <GO> the the , , <NUM> <NUM> the the <NUM> <NUM> <NUM> to to the the the for , and and <SEP> the <SEP> the the <NUM> <NUM> the <NUM> <NUM> in to <NUM> <NUM> , to to <NUM> the , for the <NUM> and <NUM>
# | tgt word:  ['roughly', 'in', ',', 'flu', 'the', 'centers']
# | prd word:  [',', 'the', '<NUM>', '<NUM>', '<NUM>', ',']
#
#
# step:  2400 | time: 15.39 | loss: 5.382
# | tgt:  <GO> his spokesman , tom parker , said <MASK> 's attorneys would respond to the complaint monday . <SEP> parker <MASK> moore <MASK> lawyers were reviewing the complaint <MASK> would respond monday
# | prd:  <GO> the , , , , , said , 's , to , to the , and <SEP> <SEP> , , , the and and the the , , to , ,
# | tgt word:  ['moore', 'said', "'s", 'and']
# | prd word:  [',', ',', 'the', ',']
#
#
# step:  2500 | time: 15.51 | loss: 4.537
# | tgt:  <GO> prosecutors said paracha , if convicted , could face at least <NUM> years in prison . <SEP> paracha faces at least <NUM> years in prison if convicted
# | prd:  <GO> the said , , in <NUM> , , , at and <NUM> and in <NUM> <SEP> <SEP> , and at and <NUM> and in , in <NUM>
# | tgt word:  ['prosecutors', 'years', 'at', 'least']
# | prd word:  ['the', 'and', 'at', 'and']
#
#
# step:  2600 | time: 15.42 | loss: 5.573
# | tgt:  <GO> but sco has hit back , <MASK> : <quote> <MASK> view ibm 's counterclaim filing <MASK> as an effort to distract attention <MASK> <MASK> flawed linux business model . <MASK> in a statement , an sco spokeman said , <quote> we <MASK> ibm 's <MASK> filing today as an effort to distract attention from its flawed linux business model
# | prd:  <GO> <quote> said the , , , , , <quote> <quote> <quote> <quote> 's , , <quote> <SEP> a to to <quote> <quote> , <quote> , <SEP> <quote> <SEP> <SEP> <SEP> in a <quote> , <GO> <quote> , said , <quote> <quote> <quote> <quote> 's <quote> <quote> <quote> as <NUM> <quote> to <quote> <quote> <NUM> to and <quote> , <quote>
# | tgt word:  ['saying', 'we', 'today', 'from', 'its', '<SEP>', 'view', 'counterclaim']
# | prd word:  [',', '<quote>', '<quote>', ',', '<quote>', '<SEP>', '<quote>', '<quote>']
#
#
# step:  2700 | time: 15.56 | loss: 6.280
# | tgt:  <GO> the institute for supply management said its manufacturing index was <NUM> <MASK> last month , up from <MASK> in april . <SEP> the institute for supply management 's manufacturing index rose <MASK> <NUM> in may from <MASK> in april , the biggest monthly <MASK> since <MASK>
# | prd:  <GO> the the for , <NUM> said to <NUM> <NUM> was <NUM> <NUM> to to , <NUM> <NUM> <NUM> in <NUM> <SEP> <SEP> the the for <NUM> <NUM> 's <NUM> <NUM> percent <NUM> <NUM> in to from <NUM> in <NUM> , the <NUM> <NUM> <NUM> <NUM> ,
# | tgt word:  ['percent', '<NUM>', 'to', '<NUM>', 'gain', 'december']
# | prd word:  ['<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>', ',']
#
#
# step:  2800 | time: 15.65 | loss: 5.520
# | tgt:  <GO> shares of eds <MASK> $ <NUM> , or <NUM> <MASK> <MASK> to $ <NUM> early wednesday on the new york stock <MASK> . <SEP> shares were off <NUM> cents , or <NUM> percent <MASK> at $ <NUM> on tuesday on the <MASK> york stock exchange
# | prd:  <GO> the of cents the $ <NUM> , <GO> <NUM> <NUM> <NUM> to $ <NUM> <NUM> on on the , <NUM> stock <NUM> to <SEP> shares to <NUM> <NUM> $ , to <NUM> percent <NUM> at $ <NUM> on <GO> on the <NUM> $ stock on
# | tgt word:  ['gained', 'percent', ',', 'exchange', ',', 'new']
# | prd word:  ['the', '<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>']
#
#
# step:  2900 | time: 15.38 | loss: 5.486
# | tgt:  <GO> marissa jaret <MASK> , as tracy <MASK> won for best actress in a musical . <SEP> newcomer marissa jaret <MASK> in <quote> hairspray <quote> bested broadway veteran bernadette peters in <MASK> gypsy <quote> <MASK> best actress in a musical
# | prd:  <GO> <quote> , , , as , , , for , , in a , <SEP> <SEP> and , , <quote> in <quote> <NUM> <quote> , , , <quote> , in <quote> , <quote> , , , in a ,
# | tgt word:  ['winokur', ',', 'winokur', '<quote>', 'for']
# | prd word:  [',', ',', '<quote>', '<quote>', ',']
#
#
# step:  3000 | time: 15.40 | loss: 6.224
# | tgt:  <GO> on monday the palestinian prime minister , mahmoud abbas , dismiss report to the palestinian parliament mt his government 's achievements in signed first <NUM> days in 25th . <SEP> palestinian prime minister mahmoud abbas must defend the record spouses his first incite days in office before shuttles today as the death toll streets powers occupied territories continues to rise
# | prd:  <GO> the was the the a the , the the , to 's to the on the and his in 's the in in on <NUM> in in the to <SEP> the the a the the , the the 's the his on , in in on to to to as the , the the the the , on to 's
# | tgt word:  ['will', 'on', 'its', 'office', 'of', '<NUM>', 'parliament', 'in', 'the']
# | prd word:  ['to', 'and', 'in', 'the', 'the', ',', 'to', 'the', 'the']
#
#
# step:  3100 | time: 15.41 | loss: 6.774
# | tgt:  <GO> the <MASK> torched randy choate and juan acevedo in the <MASK> <MASK> four runs and a <NUM>- bulge . <SEP> the mariners piled on against randy <MASK> and juan acevedo in the bottom of the <MASK>
# | prd:  <GO> the was the against was and the was in the was the the the and a <NUM> on <SEP> <SEP> the the the on against the the and the in in the in of the the
# | tgt word:  ['mariners', 'eighth', 'for', 'choate', 'inning']
# | prd word:  ['was', 'was', 'the', 'the', 'the']
#
#
# step:  3200 | time: 15.54 | loss: 6.017
# | tgt:  <GO> six vehicles , <MASK> one belonging <MASK> the <MASK> , were damaged in the powerful explosion . <SEP> several passing vehicles and an adjacent shop were also <MASK> in the explosion
# | prd:  <GO> the , , , , the , the , , to the in the the the <SEP> <SEP> the , the and a the , to also , in the ,
# | tgt word:  ['including', 'to', 'army', 'damaged']
# | prd word:  [',', ',', ',', ',']
#
#
# step:  3300 | time: 15.43 | loss: 6.130
# | tgt:  <GO> unable to find a home for him , a judge told mental health authorities they needed <MASK> <MASK> supervised housing and treatment for <MASK> somewhere <MASK> california . <SEP> the judge had told the state department of <MASK> health to <MASK> supervised housing <MASK> treatment for devries somewhere in california
# | prd:  <GO> the to , a and for to , a the he for as , for the and and for for and for for and for for for <SEP> <SEP> the to , he the to for of for for to to for for to for for for for in for
# | tgt word:  ['to', 'find', 'devries', 'in', 'mental', 'find', 'and']
# | prd word:  ['and', 'and', 'and', 'for', 'for', 'to', 'to']
#
#
# step:  3400 | time: 15.54 | loss: 5.654
# | tgt:  <GO> at <MASK> pentagon <MASK> the <MASK> of defense 's inspector general has separately been asked to investigate how the telecom licences were <MASK> . <SEP> but <MASK> source close to the pentagon said the <MASK> department 's own inspector-general had been asked <MASK> investigate how the licences were awarded
# | prd:  <GO> at the the the the the of the 's the , the to the the to to to the to the to the to <SEP> <SEP> the the the to the to said the the to 's the the , the to the to the the to the to
# | tgt word:  ['the', ',', 'department', 'awarded', 'a', 'defense', 'to']
# | prd word:  ['the', 'the', 'the', 'the', 'the', 'the', 'the']
#
#
# step:  3500 | time: 15.44 | loss: 5.266
# | tgt:  <GO> the <MASK> <MASK> saying that boykin requested it , is <MASK> his remarks . <SEP> the pentagon has begun an official investigation into boykin 's remarks
# | prd:  <GO> the said is , that the the it , is , his the <SEP> <SEP> the it has the a is is the the 's the
# | tgt word:  ['pentagon', ',', 'investigating']
# | prd word:  ['said', 'is', ',']
#
#
# step:  3600 | time: 15.38 | loss: 6.130
# | tgt:  <GO> it would <MASK> take place some time before <MASK> <NUM> in auckland . <SEP> the meeting would <MASK> be held before august <NUM>
# | prd:  <GO> it would be to be be be to to <NUM> in to <SEP> <SEP> the to to be be be to percent <NUM>
# | tgt word:  ['now', 'august', 'now']
# | prd word:  ['be', 'to', 'be']
#
#
# step:  3700 | time: 15.47 | loss: 5.313
# | tgt:  <MASK> lawtey <MASK> not the first faith-based program in florida 's prison system . <SEP> but lawtey <MASK> the first entire prison to take that path
# | prd:  <GO> the the not the <NUM> the to in to 's to to to <SEP> the the the the <NUM> the to to to that the
# | tgt word:  ['<GO>', 'is', 'is']
# | prd word:  ['<GO>', 'the', 'the']
#
#
# step:  3800 | time: 15.42 | loss: 5.750
# | tgt:  <GO> the parents want her kept alive ; her husband says <MASK> <MASK> wanted to be kept alive <MASK> . <SEP> michael schiavo has argued that his <MASK> never wanted to <MASK> kept alive artificially
# | prd:  <GO> the her to to her her , her and to and to he to be her to her to <SEP> be he has be that and to he he to to to her her
# | tgt word:  ['she', 'never', 'artificially', 'wife', 'be']
# | prd word:  ['and', 'to', 'her', 'to', 'to']
#
#
# step:  3900 | time: 15.42 | loss: 5.247
# | tgt:  <GO> the technology-laced nasdaq composite index .ixic rose <NUM> <MASK> , or <NUM> percent , <MASK> <NUM> . <SEP> the broader <MASK> & poor 's <NUM> index .spx gained <MASK> points <MASK> or <NUM> percent , to <NUM>
# | prd:  <GO> the composite index composite index index percent <NUM> <NUM> , or <NUM> percent , <NUM> <NUM> to <SEP> the index <NUM> index <NUM> 's <NUM> index points index <NUM> points <NUM> or <NUM> percent , to <NUM>
# | tgt word:  ['points', 'to', 'standard', '<NUM>', ',']
# | prd word:  ['<NUM>', '<NUM>', '<NUM>', '<NUM>', '<NUM>']
#
#
# step:  4000 | time: 15.41 | loss: 3.487
# | tgt:  <GO> the other <NUM> people inside the building - two visitors and <NUM> employees , including harrison 's ex-girlfriend - escaped without injury , aaron said . <SEP> the other <NUM> people in the building , including harrison 's ex-girlfriend , were not injured , police spokesman don aaron said
# | prd:  <GO> the 's <NUM> people people the , , 's 's and <NUM> were , , , 's <NUM> , , , <NUM> , , said <SEP> <SEP> the were <NUM> people in the , , , , 's <NUM> , were not , , in , , , said
# | tgt word:  ['inside', '-', 'harrison', '-', 'the', 'harrison', 'not']
# | prd word:  ['people', ',', ',', ',', 'the', ',', 'not']
#
#
# step:  4100 | time: 15.43 | loss: 5.539
# | tgt:  <GO> unemployment across the state fell a <MASK> of a <MASK> point last month to <NUM> percent from <MASK> <MASK> mark of <NUM> percent . <SEP> the unemployment rate <MASK> san <MASK> county dipped last month to <NUM> percent , down nearly <MASK> full percentage point from august
# | prd:  <GO> the <NUM> the to a a percent of a percent to to to to <NUM> percent from in of percent of <NUM> percent <SEP> <SEP> the a <NUM> in a percent to percent to to to <NUM> percent , percent percent percent to percent of from percent
# | tgt word:  ['half', 'percentage', 'august', "'s", 'in', 'joaquin', 'a']
# | prd word:  ['percent', 'percent', 'in', 'of', 'in', 'percent', 'percent']
#
#
# step:  4200 | time: 15.41 | loss: 3.929
# | tgt:  <GO> <quote> this is a wide-ranging and continuing investigation which is likely to result in numerous other charges , <quote> mr spitzer said . <SEP> <quote> this is a widening and continuing investigation , which is likely to result in numerous other charges , <quote> mr. spitzer said yesterday at a news conference
# | prd:  <GO> <quote> this is a is and <quote> , as is is to is in said and be , <quote> is <quote> said . <SEP> <quote> <quote> is a is and <quote> is , is is is to is in said and is , <quote> is <quote> said of at a a is
# | tgt word:  ['and', 'is', 'to', '<quote>', 'result', 'numerous', ',']
# | prd word:  ['and', 'is', 'to', '<quote>', 'is', 'said', ',']
#
#
# step:  4300 | time: 15.62 | loss: 5.051
# | tgt:  <GO> she said nelson <MASK> someone shout <MASK> <quote> let 's get the jew ! <quote> <MASK> mr. nelson heard people shout : <quote> there 's a <MASK>
# | prd:  <GO> he said <NUM> we <NUM> 's , <quote> <quote> 's , the <SEP> , <quote> <SEP> <quote> <quote> , <NUM> i , <quote> has 's a <quote>
# | tgt word:  ['heard', ',', '<SEP>', 'jew']
# | prd word:  ['we', ',', '<SEP>', '<quote>']
#
#
# step:  4400 | time: 15.43 | loss: 5.420
# | tgt:  <GO> a spokesman said : <quote> further <MASK> is under way but at this stage , given the early detection , <MASK> outlook is positive . <quote> <MASK> <quote> further testing <MASK> still under way , but at this stage , <MASK> the early detection , the outlook in <MASK> <MASK> would be positive , <MASK> the specialist said yesterday
# | prd:  <GO> a <quote> said <quote> <quote> 's , is be <quote> <SEP> at <quote> , , , the new <quote> , the shares <SEP> market . <quote> <SEP> <quote> a <quote> <quote> is be <quote> , but at this , , , the , <quote> , the market in <quote> <quote> would be <quote> , <quote> the <quote> said will
# | tgt word:  ['testing', 'the', '<SEP>', 'is', 'given', 'such', 'instances', '<quote>']
# | prd word:  [',', 'the', '<SEP>', '<quote>', ',', '<quote>', '<quote>', '<quote>']
#
#
# step:  4500 | time: 15.56 | loss: 3.323
# | tgt:  <GO> j.d. edwards shareholders will receive <NUM> of a share of peoplesoft for each share of j.d. edwards . <SEP> shareholders will get <NUM> peoplesoft share , or $ <NUM> , for each j.d. edwards share , based on recent trading prices
# | prd:  <GO> shares will shares will $ <NUM> of a share of will for $ share of $ $ . <SEP> shares will will <NUM> $ share , or $ <NUM> , for $ $ $ $ , <NUM> on $ $ <NUM>
# | tgt word:  ['each', 'edwards', 'will', 'or', 'edwards', 'trading']
# | prd word:  ['$', '$', 'will', 'or', '$', '$']
#
#
# step:  4600 | time: 15.36 | loss: 4.808
# | tgt:  <GO> shares of smithfield closed up $ <NUM> <MASK> or <NUM> percent , <MASK> <MASK> <NUM> , on the new <MASK> stock exchange . <SEP> shares <MASK> smithfield rose $ <NUM> yesterday to close at $ <NUM> , <MASK> rise of <NUM> per cent , on the new york <MASK> exchange
# | prd:  <GO> shares of shares shares up $ <NUM> $ or <NUM> percent , $ $ <NUM> , on the on on stock stock <SEP> <SEP> shares the shares shares $ <NUM> to to or at $ <NUM> , on stock of <NUM> $ $ , on the of york on shares
# | tgt word:  [',', 'at', '$', 'york', 'of', 'a', 'stock']
# | prd word:  ['$', '$', '$', 'on', 'the', 'on', 'on']
#
#
# step:  4700 | time: 15.58 | loss: 3.395
# | tgt:  <GO> <quote> canada is a small country , and it needs companies like this , deals like this . <quote> <SEP> a passionate nationalist , mr. d 'alessandro said : <quote> canada is a small country , and we need more companies like this .
# | prd:  <GO> <quote> we is a we is , and it we and we this , we our this . <quote> <SEP> a we we , <quote> we we said , <quote> we is a we we , and we we more , we this .
# | tgt word:  ['this', ',', 'mr.', 'canada', 'is', 'a']
# | prd word:  ['this', ',', '<quote>', 'we', 'is', 'a']
#
#
# step:  4800 | time: 15.50 | loss: 5.095
# | tgt:  <GO> chief merchandising officers oversee the <MASK> and development of merchandise , deciding the merchandising <MASK> of the company <MASK> or basically what it should stand for . <SEP> he or she decides <MASK> merchandising direction <MASK> the company , or basically what <MASK> should stand for
# | prd:  <GO> <quote> will will will the will and will of will , to the of to of the to , or of will it of will for <SEP> <SEP> he or he will of of of of the to , or be to of of will for
# | tgt word:  ['buying', 'direction', ',', 'the', 'of', 'it']
# | prd word:  ['will', 'to', ',', 'of', 'of', 'of']
#
#
# step:  4900 | time: 15.40 | loss: 5.159
# | tgt:  <GO> baer said <MASK> had concluded <MASK> lawyers for the two victims <quote> have shown , albeit barely ... that iraq provided <MASK> support to bin <MASK> and al-qaeda <quote> . <SEP> judge harold baer concluded wednesday <MASK> lawyers <MASK> the two victims <quote> have shown <MASK> albeit <MASK> ... that <MASK> provided material support to bin laden and al-qaida .
# | prd:  <GO> <quote> said has had said that said for the , that <quote> , that , that that that that for that , said to and that and <quote> <quote> <SEP> <SEP> said that that that in that said , the two to <quote> have that and . and that that that that . and to that . and and .
# | tgt word:  ['he', 'that', 'material', 'laden', 'that', 'for', ',', 'barely', 'iraq']
# | prd word:  ['has', 'that', ',', 'that', 'that', ',', 'and', 'and', 'that']
#
#
# step:  5000 | time: 15.55 | loss: 5.161
# | tgt:  <GO> the first biotechnology treatment <MASK> <MASK> , the constriction of the airways that <MASK> millions around the world , received approval from the us food and <MASK> <MASK> yesterday . <SEP> the first biotechnology treatment for asthma , the constriction of the <MASK> that <MASK> <MASK> of americans , received approval from the u.s. <MASK> and drug administration on friday
# | prd:  <GO> the first of that of of , the of of the of that of of of the of , of of from the of of and of of <SEP> <SEP> <SEP> the first of that for of , the of of the of that the of of said , of of from the u.s. the and of of on was
# | tgt word:  ['for', 'asthma', 'affects', 'drug', 'administration', 'airways', 'affects', 'millions', 'food']
# | prd word:  ['of', 'of', 'of', 'of', 'of', 'of', 'the', 'of', 'the']
#
#
# step:  5100 | time: 15.64 | loss: 3.418
# | tgt:  <GO> they suspect the same anarchist group that claimed responsibility for the dec. <NUM> explosions near his house , according to italian news agency ansa . <SEP> italian police investigating the prodi bomb suspect an anarchist group that claimed responsibility for dec. <NUM> explosions near his house , according to italian news agency ansa
# | prd:  <GO> they was the the for for that for for for the for <NUM> for for his to , for to for to for for <SEP> <SEP> for police for the for for for an for for that for for for for <NUM> for of his for , to to for for for for
# | tgt word:  ['suspect', 'the', 'agency', '<SEP>', 'investigating', 'his', ',']
# | prd word:  ['was', 'the', 'for', '<SEP>', 'for', 'his', ',']
#
#
# step:  5200 | time: 15.56 | loss: 5.604
# | tgt:  <GO> he is mountain of obstructing justice , witness tampering and drumbeats evidence . <SEP> quattrone , <NUM> , is chaired with obstruction of justice and commute tampering
# | prd:  <GO> he is , of was justice , and and and and <SEP> <SEP> <SEP> , , <NUM> , is , with and of and and , chief
# | tgt word:  ['accused', 'destroying', 'charged', 'witness']
# | prd word:  [',', 'and', ',', ',']
#
#
# step:  5300 | time: 15.28 | loss: 3.223
# | tgt:  <GO> the legislature returns today for a special session and they 're expected to pass a compromise bill aimed at lowering doctors ' medical malpractice insurance rates . <SEP> florida legislators return today for a special session in which they 're expected to pass a compromise bill aimed at lowering doctors ' medical malpractice insurance rates
# | prd:  <GO> the of will the for a of a and they 's a to a a of of of at of of ' a a a in <SEP> <SEP> a of the the for a the a in were they 's of to a a of to of at a a ' a war a a
# | tgt word:  ['for', 'to', 'lowering', "'", '<SEP>', 'in', 'to', 'compromise']
# | prd word:  ['for', 'to', 'of', "'", '<SEP>', 'in', 'to', 'of']
#
#
# step:  5400 | time: 15.47 | loss: 3.321
# | tgt:  <GO> mark kaiser , vice-president of marketing , and tim lee , vice-president of purchasing , were dismissed last week . <SEP> mark kaiser and tim lee , respectively us foodservice vice-presidents for marketing and purchasing , have been dismissed
# | prd:  <GO> the said , and of and , and for chief , of of and , were and of week <SEP> <SEP> the filed and said chief , for us of of for the and and , have and <SEP>
# | tgt word:  [',', 'of', ',', ',', 'been']
# | prd word:  [',', 'of', ',', ',', 'and']
#
#
# step:  5500 | time: 15.55 | loss: 4.397
# | tgt:  <MASK> the fighting around bunia <MASK> after neighboring uganda completed the withdrawal of its <MASK> than <NUM> soldiers <MASK> the town . <SEP> <MASK> fighting begun <MASK> <NUM> after neighboring uganda completed the withdrawal of its more than <NUM> soldiers from in an around bunia
# | prd:  <GO> the after from u.s. the after to after to the from of its the than <NUM> in the the in . <SEP> the after after the <NUM> after to to to the to of its more than <NUM> to from in an to from
# | tgt word:  ['<GO>', 'began', 'more', 'from', 'the', 'may']
# | prd word:  ['<GO>', 'the', 'the', 'the', 'the', 'the']
#
#
# step:  5600 | time: 15.39 | loss: 4.755
# | tgt:  <MASK> <quote> we see <MASK> first amendment to protect religious <MASK> , not crush religious liberty , <quote> said patrick mahoney <MASK> director of the christian defense coalition . <SEP> <quote> we <MASK> the call out , <MASK> said the rev. patrick j. mahoney <MASK> director of the christian defense coalition
# | prd:  <GO> <quote> we are the first to to <quote> <quote> the , not , <quote> <GO> , <quote> said , <SEP> the , of the <quote> the <SEP> <SEP> <SEP> <quote> we , the of in , <quote> said the , the the , <quote> , of the <quote> <quote> to
# | tgt word:  ['<GO>', 'the', 'liberty', ',', 'put', '<quote>', ',']
# | prd word:  ['<GO>', 'the', 'the', 'the', ',', '<quote>', '<quote>']
#
#
# step:  5700 | time: 15.47 | loss: 5.240
# | tgt:  <GO> university of michigan <MASK> mary <MASK> coleman said in a statement on the university 's <MASK> site , <quote> our fundamental values haven 't changed . <SEP> <quote> <MASK> fundamental values haven 't changed , <quote> <MASK> sue coleman , <MASK> of the university <MASK> said in a statement in ann arbor
# | prd:  <GO> <quote> of ' a statement the a said in a statement on the ' 's the <quote> , <quote> <quote> . statement . , . . <SEP> <quote> the statement ' <quote> , . , <quote> the statement ' , the of the statement said said in a . in statement <quote>
# | tgt word:  ['president', 'sue', 'web', 'our', 'mary', 'president', ',']
# | prd word:  ['a', 'the', 'the', 'the', 'the', 'the', 'said']
#
#
# step:  5800 | time: 15.73 | loss: 4.954
# | tgt:  <GO> security lights have also <MASK> installed <MASK> police have swept the grounds for booby traps . <SEP> security lights have also been <MASK> <MASK> a barn near the front gate
# | prd:  <GO> the will have also and have , , have and the the for and and . <SEP> and and have also been and the a been of the the have
# | tgt word:  ['been', 'and', 'installed', 'on']
# | prd word:  ['and', ',', 'and', 'the']
#
#
# step:  5900 | time: 15.38 | loss: 4.651
# | tgt:  <MASK> <MASK> birth on <NUM> may is revealed <MASK> in the journal science . <MASK> the scientists ' research is being published today in the journal science ( www.sciencemag.org )
# | prd:  <GO> the is on <NUM> may is in the in the journal journal . <SEP> the journal the journal is by journal in in the journal journal ( journal )
# | tgt word:  ['<GO>', 'his', 'today', '<SEP>']
# | prd word:  ['<GO>', 'the', 'the', '<SEP>']
#
#
# step:  6000 | time: 15.48 | loss: 3.154
# | tgt:  <GO> bush also hoped to polish his anti-aids credentials in uganda , which has been hailed as an african pioneer in fighting the killer disease . <SEP> president bush flies to uganda friday hoping to polish his anti- aids credentials in a country hailed as an african pioneer in fighting the epidemic
# | prd:  <GO> he also be to be his credentials credentials in credentials , be has been credentials as an economic credentials in fighting the the economic . <SEP> president bush credentials to uganda friday credentials to uganda his credentials credentials credentials in a to credentials as an credentials credentials in fighting the uganda
# | tgt word:  ['<GO>', 'bush', 'hoped', 'been', 'his', 'hailed', 'as']
# | prd word:  ['<GO>', 'he', 'be', 'been', 'his', 'credentials', 'as']
#
#
# step:  6100 | time: 15.37 | loss: 2.655
# | tgt:  <GO> the dollar gained against the euro , yen and swiss franc after september u.s. retail sales figures came in slightly weaker than consensus forecasts . <SEP> the greenback rose steeply against the euro , yen and swiss franc despite weaker-than-expected september u.s. retail sales figures
# | prd:  <GO> the dollar euro against the euro , euro and euro dollar after and u.s. sales the against sales in sales sales the sales <SEP> <SEP> <SEP> the dollar the the in the euro , the and dollar dollar dollar sales sales u.s. sales sales sales
# | tgt word:  ['euro', 'september', 'came', 'in', 'despite', 'u.s.']
# | prd word:  ['euro', 'and', 'sales', 'in', 'dollar', 'u.s.']
#
#
# step:  6200 | time: 15.64 | loss: 4.410
# | tgt:  <GO> the <NUM> 5 <MASK> <NUM> <MASK> note maturing in april <MASK> gained <NUM> / <NUM> to <NUM> <MASK> / <NUM> , lowering its yield <NUM> basis points to <NUM> percent . <SEP> the yield <MASK> the <NUM> percent note maturing in <NUM> <MASK> <MASK> basis points to <NUM> percent
# | prd:  <GO> the <NUM> index , <NUM> percent index percent in percent <NUM> rose <NUM> percent <NUM> to <NUM> <NUM> percent <NUM> , percent its to <NUM> percent points to <NUM> percent . <SEP> the percent in the <NUM> percent index percent in <NUM> percent <NUM> percent points to <NUM> percent
# | tgt word:  ['/', 'percent', '<NUM>', '13', 'on', 'fell', '<NUM>']
# | prd word:  [',', 'percent', '<NUM>', '<NUM>', 'in', 'percent', '<NUM>']
#
#
# step:  6300 | time: 15.44 | loss: 2.574
# | tgt:  <GO> the broader standard & poor 's <NUM> index < .spx > edged down <NUM> points , or <NUM> percent , to <NUM> . <SEP> the standard & poor 's <NUM> index shed <NUM> , or <NUM> percent , to <NUM> as of <NUM> : <NUM> a.m. in new york
# | prd:  <GO> the standard standard & index 's <NUM> index index index index points down <NUM> points , or <NUM> percent , to <NUM> . <SEP> the standard & index 's <NUM> index index <NUM> , or <NUM> percent , to <NUM> as of <NUM> : <NUM> points in new .
# | tgt word:  ['<GO>', 'the', '<NUM>', 'index', 'shed', 'to', 'as']
# | prd word:  ['<GO>', 'the', '<NUM>', 'index', 'index', 'to', 'as']
#
#
# step:  6400 | time: 15.47 | loss: 2.867
# | tgt:  <GO> sales - a figure watched closely as a barometer of its health - rose <NUM> percent instead of falling as many industry experts had predicted . <SEP> it also disclosed that sales -- a figure closely watched by analysts as a barometer of its health -- were significantly higher than industry experts expected
# | prd:  <GO> sales more a than sales than as a its of its as more <NUM> <NUM> percent more of sales as as the a had sales <SEP> <SEP> it also month that sales as a more <NUM> than by its as a sales of its as as were sales sales than sales a sales
# | tgt word:  ['-', 'as', 'many', 'industry', 'had', 'than', 'expected']
# | prd word:  ['more', 'as', 'as', 'the', 'had', 'than', 'sales']
#
#
# step:  6500 | time: 15.53 | loss: 4.852
# | tgt:  <GO> <MASK> association of south east asian nations groups brunei , cambodia , indonesia , laos , malaysia <MASK> myanmar , the philippines , <MASK> , thailand , and vietnam . <SEP> asean comprises <MASK> , <MASK> , indonesia , laos , malaysia , myanmar , the philippines , <MASK> , thailand and <MASK>
# | prd:  <GO> the the of , , the singapore the , , philippines , philippines , philippines , , , philippines , the , , and , philippines , and philippines . <SEP> philippines philippines philippines , , , philippines , philippines , , , philippines , the philippines , philippines , philippines and ,
# | tgt word:  ['the', ',', 'singapore', 'brunei', 'cambodia', 'singapore', 'vietnam']
# | prd word:  ['the', ',', 'and', 'philippines', ',', 'philippines', ',']
#
#
# step:  6600 | time: 15.47 | loss: 2.645
# | tgt:  <GO> nterprise linux services is expected to be available before then end of this year . <SEP> beta versions of nterprise linux services are expected to be available on certain hp proliant servers in july
# | prd:  <GO> also also also is expected to be the be the be of this year . <SEP> end is of expected be will are be to be available on be be be <SEP> in expected
# | tgt word:  ['be', 'this', 'of', 'be', 'servers']
# | prd word:  ['be', 'this', 'of', 'be', '<SEP>']
#
#
# step:  6700 | time: 15.39 | loss: 4.598
# | tgt:  <GO> a <MASK> bomb , evidently <MASK> by <MASK> other woman , <MASK> not explode ; the authorities detonated the explosives later . <SEP> a second bomb , evidently carried by <MASK> other woman , did not explode ; the authorities found explosives <MASK> detonated them afterward
# | prd:  <GO> a mother , , , was by the other mother , , not said , the not with the said said . <SEP> a the , , lawyer did by the other mother , not not the , the the the lawyer the did the the
# | tgt word:  ['second', 'carried', 'the', 'did', 'the', 'and']
# | prd word:  ['mother', 'was', 'the', ',', 'the', 'the']
#
#
# step:  6800 | time: 15.41 | loss: 4.865
# | tgt:  <GO> sun microsystems inc. on <MASK> said it had <MASK> <NUM> new third-party systems and <NUM> new components to its hardware <MASK> list for the solaris x86 operating system <MASK> edition . <SEP> the vendor has added <MASK> new <MASK> systems and <NUM> new components to the operating system <MASK> hardware <MASK> list ( hcl )
# | prd:  <GO> this new inc. on <NUM> said it had $ <NUM> new , ( and <NUM> new new to its new new new for the ) new $ to new new . <SEP> the new has , on new new ( and <NUM> new new to the new ( new new new new ( new )
# | tgt word:  ['thursday', 'added', 'compatibility', 'platform', '<NUM>', 'third-party', "'s", 'compatibility']
# | prd word:  ['<NUM>', '$', 'new', 'new', 'on', 'new', 'new', 'new']
#
#
# step:  6900 | time: 15.47 | loss: 4.419
# | tgt:  <GO> the statewide unemployment rate fell to <MASK> percent , down <MASK> a <MASK> <NUM> percent in august . <SEP> <MASK> unemployment rate in san joaquin county dipped last month to <NUM> percent , down <MASK> <MASK> full percentage point from august
# | prd:  <GO> the unemployment unemployment month down to <NUM> percent , down , a to <NUM> percent in percent <SEP> <SEP> the unemployment unemployment in a in a down last month to <NUM> percent , down a in in in a from percent
# | tgt word:  ['<NUM>', 'from', 'revised', 'the', 'nearly', 'a']
# | prd word:  ['<NUM>', ',', 'to', 'the', 'a', 'in']
#
#
# step:  7000 | time: 15.57 | loss: 4.563
# | tgt:  <GO> kansas department of health and environment records show <MASK> were <MASK> abortions performed on <MASK> age <MASK> <MASK> younger last year . <SEP> statistics from the kansas department of health and environment show that <NUM> abortions <MASK> performed in the state last year
# | prd:  <GO> the the of the and the and and and were and year and on the percent <NUM> the a last year . <SEP> state from the and the of and and and and that <NUM> <NUM> the state in the state a year
# | tgt word:  ['there', '<NUM>', 'girls', '<NUM>', 'and', 'were']
# | prd word:  ['and', 'and', 'the', '<NUM>', 'the', 'the']
#
#
# step:  7100 | time: 15.56 | loss: 4.218
# | tgt:  <GO> the council comprises <NUM> shi 'ites , five sunni arabs , <MASK> kurds , an assyrian christian and a <MASK> . <SEP> the council includes <MASK> shiites , five kurds , five <MASK> , <MASK> christian and one turkoman
# | prd:  <GO> the spokesman , <NUM> council , , for for for , for for , an for al-dandani and a for . <SEP> the , five <NUM> al-dandani , for council , for five , , , and one including
# | tgt word:  ['five', 'turkmen', '<NUM>', 'sunnis', 'one']
# | prd word:  ['for', 'for', '<NUM>', 'five', ',']
#
#
# step:  7200 | time: 15.41 | loss: 4.522
# | tgt:  <MASK> the dow jones industrial average <MASK> down <NUM> points , <MASK> <NUM> % , at <MASK> , <MASK> the nasdaq fell <NUM> points , or <NUM> % <MASK> to <NUM> . <SEP> in early trading , the dow jones <MASK> average was up <NUM> , or <NUM> percent , at <NUM> , having gained <MASK> on tuesday
# | prd:  <GO> the dow dow industrial average average down <NUM> points , average <NUM> percent , at <NUM> , , the nasdaq fell <NUM> points , or <NUM> percent , to <NUM> . <SEP> in at trading , the dow industrial <NUM> average was up <NUM> , or <NUM> percent , at <NUM> , average average <NUM> on on
# | tgt word:  ['<GO>', 'ended', 'or', '<NUM>', 'while', ',', 'industrial', '<NUM>']
# | prd word:  ['<GO>', 'average', 'average', '<NUM>', ',', ',', '<NUM>', '<NUM>']
#
#
# ...
# | tgt word:  ['<GO>', 'co-conspirator', 'destroyed', 'coconspirator', 'together', 'destroyed']
# | prd word:  ['<GO>', 'building', 'building', 'that', 'that', 'building']
#
#
# step:  7700 | time: 15.55 | loss: 4.135
# | tgt:  <GO> the victim , who was also not <MASK> , was <MASK> to kings county hospital in <quote> <MASK> critical <MASK> condition , czartoryski said . <SEP> the shooting victim was taken to kings county <MASK> center , where he <MASK> died , the police said
# | prd:  <GO> the was , who was also not was , was , to he hospital hospital in <quote> the , <quote> condition , <quote> said . <SEP> the was was was taken to <quote> was , hospital , where he , died , the police said
# | tgt word:  ['identified', 'taken', 'extremely', '<quote>', 'hospital', 'later']
# | prd word:  ['was', ',', 'the', '<quote>', ',', ',']
#
#
# step:  7800 | time: 15.49 | loss: 3.973
# | tgt:  <GO> gartner analysts said that businesses are not yet feeling confident <MASK> to upgrade corporate <MASK> . <SEP> <MASK> <MASK> more , companies are not <MASK> confident enough to replace older pcs , the analyst firm said
# | prd:  <GO> they they said that enough are not enough companies enough enough to enough enough enough . <SEP> that , more , companies are not they enough enough to people enough enough , the enough new said
# | tgt word:  ['enough', 'pcs', 'what', "'s", 'feeling']
# | prd word:  ['enough', 'enough', 'that', ',', 'they']
#
#
# step:  7900 | time: 15.58 | loss: 2.711
# | tgt:  <GO> microsoft fell <NUM> percent before the open to $ <NUM> from thursday 's close of $ <NUM> . <SEP> shares in microsoft slipped <NUM> percent in after-hours trade to $ <NUM> from a nasdaq close of $ <NUM>
# | prd:  <GO> shares rose <NUM> percent to the , to $ <NUM> from thursday 's close of $ <NUM> . <SEP> shares in shares $ <NUM> percent in shares rose to $ <NUM> from a rose percent of $ <NUM>
# | tgt word:  ['open', 'of', '<NUM>', 'shares', 'close']
# | prd word:  [',', 'of', '<NUM>', 'shares', 'percent']
#
#
# step:  8000 | time: 15.43 | loss: 4.151
# | tgt:  <GO> also tuesday <MASK> the united states also released more <MASK> prisoners of war , and officials announced that all would soon be let go . <SEP> meanwhile in southern <MASK> , the united states released more iraqi <MASK> of war , and <MASK> announced that <MASK> would be <MASK> go soon
# | prd:  <GO> also tuesday , the united states also u.s. more the began of war , and officials announced that all would bush be would . . <SEP> states in states year , the united states u.s. more iraqi year of war , and it announced that will would be would year in
# | tgt word:  [',', 'iraqi', 'iraq', 'prisoners', 'officials', 'all', 'let']
# | prd word:  [',', 'the', 'year', 'year', 'it', 'will', 'would']
#
#
# step:  8100 | time: 15.69 | loss: 2.396
# | tgt:  <GO> world airways inc. and north american airlines inc. also have filed applications seeking authority to provide service to iraq . <SEP> cargo carriers world airways inc. and north american airlines inc. have also applied for permission to fly to baghdad , mosley said
# | prd:  <GO> world inc. inc. and north american inc. inc. also have have seeking seeking to to and american to on . <SEP> inc. inc. world inc. inc. and north american inc. inc. have also inc. for inc. to inc. to inc. , seeking said
# | tgt word:  ['have', 'filed', 'iraq', 'airways', 'also', 'fly']
# | prd word:  ['have', 'have', 'on', 'inc.', 'also', 'inc.']
#
#
# step:  8200 | time: 15.60 | loss: 5.163
# | tgt:  jdec.o there are now <NUM> active probable cases in the gta , weeks juli <NUM> cases on june lawmakers . <SEP> and , globally , the number of active probable cases has declined renewed <NUM>
# | prd:  <GO> there are about <NUM> cases about cases in the <NUM> , were and <NUM> <NUM> on <NUM> <NUM> . <SEP> and , <NUM> , the number of and and <NUM> has , and <NUM>
# | tgt word:  ['<GO>', 'compared', 'with', '<NUM>', 'to']
# | prd word:  ['<GO>', 'were', 'and', '<NUM>', 'and']
#
#
# step:  8300 | time: 15.64 | loss: 3.578
# | tgt:  <MASK> at his request , <MASK> will be reassigned within the district . <SEP> district superintendent <MASK> chester <MASK> told reporters monday that mccrackin will be reassigned within the district
# | prd:  <GO> at his be , he will be be in the district . <SEP> district be be will he told be monday that reassigned will be reassigned . the district
# | tgt word:  ['<GO>', 'he', 'j.', 'floyd']
# | prd word:  ['<GO>', 'he', 'be', 'he']
#
#
# step:  8400 | time: 15.45 | loss: 3.727
# | tgt:  <GO> each count has a maximum penalty of <NUM> years in <MASK> and $ <NUM> million fine . <MASK> both executives face up to <MASK> years <MASK> prison and a $ <NUM> million <MASK> for securities fraud
# | prd:  <GO> in million has a million million of <NUM> years in million and $ <NUM> <NUM> million . <SEP> that state years up to <NUM> million in million and a $ <NUM> million million for million million
# | tgt word:  ['prison', '<SEP>', '<NUM>', 'in', 'fine']
# | prd word:  ['million', '<SEP>', '<NUM>', 'in', 'million']
#
#
# step:  8500 | time: 15.66 | loss: 2.014
# | tgt:  <GO> still others cite the difficulty of assembling a group of subjects whose depression is of comparable severity , increasing the chances that the effectiveness of the medication will be diffused . <SEP> still others cite the difficulty of assembling a group of subjects whose depression is of comparable severity , a problem that complicates the task of properly measuring effectiveness
# | prd:  <GO> still difficulty of the difficulty of task a group of difficulty the depression is of difficulty depression , task the that that the difficulty of the will will be task . <SEP> still difficulty difficulty the difficulty of depression a group of difficulty the depression is of difficulty difficulty , a task that depression the task of task difficulty effectiveness
# | tgt word:  ['be', 'still', 'cite', 'whose', 'is', 'of', 'task', 'properly', 'measuring']
# | prd word:  ['be', 'still', 'difficulty', 'the', 'is', 'of', 'task', 'task', 'difficulty']
#
#
# step:  8600 | time: 15.80 | loss: 1.778
# | tgt:  <GO> federal offices were to remain closed for a second day overnight ( friday us time ) . <SEP> the government shut down in washington , and federal offices were to remain closed yesterday
# | prd:  <GO> federal closed were to remain closed for a federal <NUM> monday ( friday us time ) . <SEP> the have closed the in washington , and federal offices were to remain closed yesterday
# | tgt word:  ['were', 'overnight', '(', 'washington']
# | prd word:  ['were', 'monday', '(', 'washington']
#
#
# step:  8700 | time: 15.53 | loss: 3.469
# | tgt:  <GO> sun microsystems <MASK> on thursday said it had added <NUM> new third-party systems and <MASK> new components <MASK> its hardware compatibility list for <MASK> solaris x86 <MASK> system platform edition . <SEP> the <MASK> has added <NUM> new third-party systems and <MASK> new components to the operating system 's <MASK> compatibility list ( hcl )
# | prd:  <GO> new new <NUM> on thursday said it had added <NUM> new <NUM> <NUM> and <NUM> new new to its new hardware new for the ibm ibm new system new <NUM> . <SEP> the microsoft has added <NUM> new , <NUM> and <NUM> new ibm to the new system 's new new ) ( hardware )
# | tgt word:  ['inc.', '<NUM>', 'to', 'the', 'operating', 'vendor', '<NUM>', 'hardware']
# | prd word:  ['<NUM>', '<NUM>', 'to', 'the', 'new', 'microsoft', '<NUM>', 'new']
#
#
# step:  8800 | time: 15.59 | loss: 4.431
# | tgt:  <GO> the onenote note-taking tool is listed at â£ <NUM> while the infopath xml <MASK> extensible markup <MASK> ) <MASK> gathering application is priced at â£ <NUM> . <SEP> the onenote note-taking tool is listed at $ <NUM> while the <MASK> <MASK> data <MASK> <MASK> is priced at $ <NUM>
# | prd:  <GO> the nasdaq the tool is â£ at â£ <NUM> at the â£ â£ is <NUM> <NUM> percent the , the nasdaq is <NUM> at $ <NUM> <SEP> <SEP> the microsoft the nasdaq is nasdaq at $ <NUM> while the at the <NUM> at nasdaq is <NUM> at $ <NUM>
# | tgt word:  ['(', 'language', 'data', 'infopath', 'xml', 'gathering', 'application']
# | prd word:  ['is', 'percent', ',', 'at', 'the', 'at', 'nasdaq']
#
#
# step:  8900 | time: 15.60 | loss: 2.486
# | tgt:  <GO> barry callebaut will be able to use brach 's retail network to sell products made from its german subsidiary stollwerck , which makes chocolate products not sold in the united states . <SEP> barry callebaut will be able to use brach 's retail network to sell products made from its german subsidiary stollwerck , which makes chocolate products unknown to the american market
# | prd:  <GO> microsoft products will be products to products microsoft 's products products to products products made from its products products products , which products chocolate products not products in the united states . <SEP> products products will be products to products products 's products products to sell products , from its products products products , which products products products products to the american microsoft
# | tgt word:  ['be', 'subsidiary', ',', 'sold', 'callebaut', 'brach', 'german', 'which', 'unknown']
# | prd word:  ['be', 'products', ',', 'products', 'products', 'products', 'products', 'which', 'products']
#
#
# step:  9000 | time: 15.66 | loss: 4.036
# | tgt:  <GO> the broader standard & glaxosmithkline 's <NUM> index .spx gained <NUM> points , or <NUM> percent , at <NUM> . <SEP> the technology-laced reputation composite concorde < .ixic villafranca rose <NUM> points , or stabilised percent , to <NUM>
# | prd:  <GO> the broader standard & index 's <NUM> index .spx rose <NUM> points , or <NUM> percent , at <NUM> . <SEP> the nasdaq nasdaq the index index index > rose <NUM> points , or <NUM> percent , to <NUM>
# | tgt word:  ['poor', 'nasdaq', 'index', '>', '<NUM>']
# | prd word:  ['index', 'nasdaq', 'index', '>', '<NUM>']
#
#
# step:  9100 | time: 15.66 | loss: 1.505
# | tgt:  <GO> the standard & poor 's <NUM> index lost <NUM> , or <NUM> percent , to <NUM> as of <NUM> : <NUM> a.m. in new york . <SEP> the broad standard & poor 's <NUM> index .spx shed <NUM> of a point , or just <NUM> percent , to <NUM>
# | prd:  <GO> the standard & & 's <NUM> index index <NUM> , or <NUM> percent , to <NUM> as of <NUM> : <NUM> points in new york . <SEP> the & standard & poor 's <NUM> index & index <NUM> of a percent , or : <NUM> percent , to <NUM>
# | tgt word:  ['index', '<NUM>', 'in', 'the', 'index', '<NUM>', 'a']
# | prd word:  ['index', '<NUM>', 'in', 'the', 'index', '<NUM>', 'a']
#
#
# step:  9200 | time: 15.40 | loss: 3.237
# | tgt:  <GO> spot <MASK> was quoted at $ <NUM> / <NUM> an ounce <MASK> <NUM> <MASK> , having marched up to $ <NUM> <MASK> <MASK> level not seen since <MASK> <NUM> . <SEP> spot gold was quoted at $ <NUM> / <NUM> an ounce at <NUM> gmt <MASK> having darted as high <MASK> $ <NUM> <MASK> a level not seen since february <NUM>
# | prd:  <GO> spot ounce was ounce at $ <NUM> $ <NUM> an ounce $ <NUM> gmt , ounce ounce up to $ <NUM> $ was was not $ since $ <NUM> . <SEP> at gold was ounce at $ <NUM> at <NUM> an ounce at <NUM> $ , ounce gmt as high at $ <NUM> at a was not $ since at <NUM>
# | tgt word:  ['gold', 'at', 'gmt', '--', 'a', 'february', ',', 'as', '--']
# | prd word:  ['ounce', '$', 'gmt', '$', 'was', '$', ',', 'at', 'at']
#
#
# step:  9300 | time: 15.38 | loss: 3.209
# | tgt:  <GO> gov. rick perry has said that while he opposes <MASK> expansion , <MASK> would be reluctant to veto continuation of the <MASK> commission . <SEP> gov. rick perry opposes expansion <MASK> gambling but <MASK> said he would <MASK> <quote> hard-pressed <quote> to <MASK> the lottery sunset bill
# | prd:  <GO> he has has has said that while he <quote> has veto , would would be government to opposes veto of the bill commission . <SEP> has many has to has of has but has said he would , <quote> <quote> <quote> to bill the the that bill
# | tgt word:  ['gambling', 'he', 'lottery', 'of', 'has', 'be', 'veto']
# | prd word:  ['has', 'would', 'bill', 'of', 'has', ',', 'bill']
#
#
# step:  9400 | time: 15.55 | loss: 3.141
# | tgt:  <GO> <quote> the <MASK> that tony abbott is in <MASK> way a <MASK> political <MASK> couldn 't be more <MASK> , <MASK> mr howard said . <SEP> <quote> the idea that tony abbott is in some way a one-dimensional political head kicker couldn 't be <MASK> wrong .
# | prd:  <GO> <quote> the 't that that one-dimensional is in the way a one-dimensional one-dimensional be be 't be more one-dimensional , <quote> <quote> one-dimensional said . <SEP> <quote> the one-dimensional that that one-dimensional is in some 't a one-dimensional a be one-dimensional more 't be one-dimensional wrong .
# | tgt word:  ['idea', 'some', 'one-dimensional', 'head-kicker', 'wrong', '<quote>', 'more']
# | prd word:  ["'t", 'the', 'one-dimensional', 'be', 'one-dimensional', '<quote>', 'one-dimensional']
#
#
# step:  9500 | time: 15.25 | loss: 4.219
# | tgt:  denied the lamented conditionally on thursday its staff was preparing to draw up rules to combat trading abuses . <SEP> last week the securities and exchange commission said its buying was preparing to draw up rules to false trading abuses
# | prd:  <GO> the said thursday on thursday its staff was related to securities up close to close trading exchange . <SEP> last week the commission and exchange commission said its kennedy was related to securities up securities to to trading close
# | tgt word:  ['<GO>', 'sec', 'said', 'staff', 'combat']
# | prd word:  ['<GO>', 'said', 'thursday', 'kennedy', 'to']
#
#
# step:  9600 | time: 15.45 | loss: 1.889
# | tgt:  <GO> the rate of skin cancer has tripled since the 1950s in norway and sweden , according to the study . <SEP> the study also found that skin cancer nearly tripled in norway and sweden since the 1950s
# | prd:  <GO> the last of risk cancer has sweden since the study in sweden and sweden , according to the study . <SEP> the study also found that study cancer <NUM> study in study and sweden since the study
# | tgt word:  ['sweden', 'found', 'cancer', 'nearly', 'the']
# | prd word:  ['sweden', 'found', 'cancer', '<NUM>', 'the']
#
#
# step:  9700 | time: 15.54 | loss: 3.348
# | tgt:  <GO> u.s. forces recently apprehended some <NUM> suspected foreign <MASK> <MASK> the syrian border and are now interrogating them . <SEP> <MASK> third armored <MASK> regiment recently <MASK> about <NUM> suspected fighters near the syrian border , officials said
# | prd:  <GO> u.s. forces recently killed some <NUM> suspected foreign syrian near the near suspected and are but suspected them . <SEP> the u.s. suspected cavalry forces recently suspected about <NUM> <NUM> suspected of the syrian suspected , officials said
# | tgt word:  ['militants', 'near', 'the', 'cavalry', 'apprehended']
# | prd word:  ['syrian', 'near', 'the', 'cavalry', 'suspected']
#
#
# step:  9800 | time: 15.63 | loss: 3.225
# | tgt:  <GO> representatives for puretunes could not <MASK> be reached <MASK> comment wednesday . <SEP> puretunes representatives could not be located thursday to comment on <MASK> suit
# | prd:  <GO> the for comment could not could be reached not comment wednesday . <SEP> comment comment could not be be thursday to comment on the comment
# | tgt word:  ['immediately', 'for', 'the']
# | prd word:  ['could', 'not', 'the']
#
#
# step:  9900 | time: 15.49 | loss: 3.226
# | tgt:  <GO> elena slough , considered to be the nation 's oldest <MASK> <MASK> the third oldest person in the world , died early sunday <MASK> . <SEP> elena slough , considered to be the oldest <MASK> in the <MASK> and the third oldest <MASK> in the world , <MASK> died
# | prd:  <GO> oldest oldest , person to be the on 's person person in the third oldest in in the world , in early sunday oldest . <SEP> person oldest , considered to be the person be in the person and the third oldest person in the world , , died
# | tgt word:  ['person', 'and', 'morning', 'person', 'us', 'person', 'has']
# | prd word:  ['person', 'in', 'oldest', 'be', 'person', 'person', ',']
