# %%
# Mount Google Drive to Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!ls -al
# %cd '/content/drive/My Drive/NLP/Part2'
#!ls -al
# !pwd
# Out:
# /content/drive/My Drive/NLP/Part2
# /content/drive/My Drive/NLP/Part2

# %% [markdown]
# # 作業 : 調整 ELMo 模型的不同訓練參數

# %% [markdown]
# # [作業目標]
# - 調整 ELMo 模型的不同參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [作業重點]
# - 調整 ELMo 模型的不同訓練參數, 分別觀察 loss 數據並比較

# %% [markdown]
# # [參數說明]
# - UNITS : LSTM 特徵維度，即每一筆訓練輸入單字的個數
# - N_LAYERS : LSTM 堆疊的層數
# - BATCH_SIZE : 訓練批次大小，即幾筆資料合併做一次倒傳遞
# - LEARNING_RATE : 學習速率，影響收斂的快慢，須配合 BATCH_SIZE 調整

# %% [markdown]
# # 程式說明
# - 程式採用 tensorflow2 / keras 寫作, 執行前請先安裝 tensorflow 2.0
# - 本程式執行時, 請將 utils.py 與執行檔放置於同一目錄下
# - 程式來源 : 莫煩Python-ELMo:一詞多義 https://mofanpy.com/tutorials/machine-learning/nlp/elmo/

# %%
# [Deep contextualized word representations](https://arxiv.org/pdf/1802.05365.pdf)
from tensorflow import keras
import tensorflow as tf
import utils    # this refers to utils.py in my [repo](https://github.com/MorvanZhou/NLP-Tutorials/)
import time
import os

class ELMo(keras.Model):
    def __init__(self, v_dim, emb_dim, units, n_layers, lr):
        super().__init__()
        self.n_layers = n_layers
        self.units = units

        # encoder
        self.word_embed = keras.layers.Embedding(
            input_dim=v_dim, output_dim=emb_dim,  # [n_vocab, emb_dim]
            embeddings_initializer=keras.initializers.RandomNormal(0., 0.001),
            mask_zero=True,
        )
        # forward lstm
        self.fs = [keras.layers.LSTM(units, return_sequences=True) for _ in range(n_layers)]
        self.f_logits = keras.layers.Dense(v_dim)
        # backward lstm
        self.bs = [keras.layers.LSTM(units, return_sequences=True, go_backwards=True) for _ in range(n_layers)]
        self.b_logits = keras.layers.Dense(v_dim)

        self.cross_entropy1 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.cross_entropy2 = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
        self.opt = keras.optimizers.Adam(lr)

    def call(self, seqs):
        embedded = self.word_embed(seqs)        # [n, step, dim]
        """
        0123    forward
        1234    forward predict
         1234   backward 
         0123   backward predict
        """
        mask = self.word_embed.compute_mask(seqs)
        fxs, bxs = [embedded[:, :-1]], [embedded[:, 1:]]
        for fl, bl in zip(self.fs, self.bs):
            fx = fl(
                fxs[-1], mask=mask[:, :-1], initial_state=fl.get_initial_state(fxs[-1])
            )           # [n, step-1, dim]
            bx = bl(
                bxs[-1], mask=mask[:, 1:], initial_state=bl.get_initial_state(bxs[-1])
            )  # [n, step-1, dim]
            fxs.append(fx)      # predict 1234
            bxs.append(tf.reverse(bx, axis=[1]))    # predict 0123
        return fxs, bxs

    def step(self, seqs):
        with tf.GradientTape() as tape:
            fxs, bxs = self.call(seqs)
            fo, bo = self.f_logits(fxs[-1]), self.b_logits(bxs[-1])
            loss = (self.cross_entropy1(seqs[:, 1:], fo) + self.cross_entropy2(seqs[:, :-1], bo))/2
        grads = tape.gradient(loss, self.trainable_variables)
        self.opt.apply_gradients(zip(grads, self.trainable_variables))
        return loss, (fo, bo)

    def get_emb(self, seqs):
        fxs, bxs = self.call(seqs)
        xs = [tf.concat((f[:, :-1, :], b[:, 1:, :]), axis=2).numpy() for f, b in zip(fxs, bxs)]
        for x in xs:
            print("layers shape=", x.shape)
        return xs


def train(model, data, step):
    t0 = time.time()
    for t in range(step):
        seqs = data.sample(BATCH_SIZE)
        loss, (fo, bo) = model.step(seqs)
        if t % 80 == 0:
            fp = fo[0].numpy().argmax(axis=1)
            bp = bo[0].numpy().argmax(axis=1)
            t1 = time.time()
            print(
                "\n\nstep: ", t,
                "| time: %.2f" % (t1 - t0),
                "| loss: %.3f" % loss.numpy(),
                "\n| tgt: ", " ".join([data.i2v[i] for i in seqs[0] if i != data.pad_id]),
                "\n| f_prd: ", " ".join([data.i2v[i] for i in fp if i != data.pad_id]),
                "\n| b_prd: ", " ".join([data.i2v[i] for i in bp if i != data.pad_id]),
                )
            t0 = t1
    os.makedirs("./visual/models/elmo", exist_ok=True)
    model.save_weights("./visual/models/elmo/model.ckpt")


def export_w2v(model, data):
    model.load_weights("./visual/models/elmo/model.ckpt")
    emb = model.get_emb(data.sample(4))
    print(emb)


if __name__ == "__main__":
    utils.set_soft_gpu(True)
    UNITS = 256
    N_LAYERS = 4
    BATCH_SIZE = 16
    LEARNING_RATE = 2e-3
    d = utils.MRPCSingle("./MRPC", rows=2000)
    print("num word: ", d.num_word)
    m = ELMo(d.num_word, emb_dim=UNITS, units=UNITS, n_layers=N_LAYERS, lr=LEARNING_RATE)
    train(m, d, 10000)
    export_w2v(m, d)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# num word:  12880
#
#
# step:  0 | time: 5.70 | loss: 9.463
# | tgt:  <GO> the diocese reached a settlement in <NUM> involving five priests and <NUM> plaintiffs for an undisclosed sum . <SEP>
# | f_prd:  lance lance kidnappers kidnappers existing existing existing existing surrendered surrendered surrendered surrendered surrendered surrendered glove son son emeryville-based emeryville-based emeryville-based
# | b_prd:  sprayregen sprayregen sprayregen adel adel adel 40g-byte 40g-byte 40g-byte abrupt abrupt abrupt abrupt abrupt abrupt abrupt mediterranean vocal alfonseca
#
#
# step:  80 | time: 9.44 | loss: 8.046
# | tgt:  <GO> uk retail like-for-like sales for the <NUM> weeks to december <NUM> were flat , with gross margin down two percentage points . <SEP>
# | f_prd:  the , , , , , , , , , , , , , , , , , , , , , , ,
# | b_prd:  , , , , , , , , , , , , , , , , , , , , , , . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  160 | time: 9.34 | loss: 7.604
# | tgt:  <GO> deposit and loan growth , strong investment banking and trading results and strong growth in mortgage and card revenues drove this quarter 's results . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the the the the . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  240 | time: 9.39 | loss: 7.601
# | tgt:  <GO> many compensation experts had predicted carty would get a generous severance deal because his voluntary resignation helped keep the concessions deals in place . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the the . . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  320 | time: 9.28 | loss: 7.254
# | tgt:  <GO> <quote> it 's probably not the easiest time to come in and take over the shuttle program , <quote> mr. parsons said at a news conference at nasa headquarters . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the the the the the the the the the the the the the the the . . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  400 | time: 9.29 | loss: 7.100
# | tgt:  <GO> from <NUM> to <NUM> , there were <NUM> reported sexual assaults at the academy . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  480 | time: 9.32 | loss: 7.374
# | tgt:  <GO> bryant presented himself to authorities last friday and was released after posting $ <NUM> bail . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the the
# | b_prd:  the the the the the the the the the the the the the the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  560 | time: 9.31 | loss: 7.007
# | tgt:  <GO> it is <quote> in the hands of mr newton <quote> as a us space agency ( nasa ) astronaut once put it . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the the the the the the the the the <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the the the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  640 | time: 9.37 | loss: 6.942
# | tgt:  <GO> about two hours later , his body , wrapped in a blanket , was found dumped a few blocks away . <SEP>
# | f_prd:  the the the the the the the the the the the the the the the . . . . . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> the the the the the the the the the the the the the <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  720 | time: 9.37 | loss: 6.882
# | tgt:  <GO> a council of up to nine iraqis probably will lead the countrys interim government through the coming months , the u.s. civil administrator said monday . <SEP>
# | f_prd:  the the the the the the the the the the the the the the , , . . . . . . . . . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , the the the the the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  800 | time: 9.35 | loss: 6.669
# | tgt:  <GO> shares of corixa fell <NUM> cents to $ <NUM> as of <NUM> : <NUM> p.m. <SEP>
# | f_prd:  the the the the the the the , , , , , , , ,
# | b_prd:  , , , , , , , , , , , , , , <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  880 | time: 9.37 | loss: 6.739
# | tgt:  <GO> also at increased risk are those with suppressed immune systems due to illness or medicines . <SEP>
# | f_prd:  the the the the the the the the the , , , , , , .
# | b_prd:  <GO> , , , , , , , , , , , , <NUM> <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  960 | time: 9.31 | loss: 6.793
# | tgt:  <GO> brian rohrbough , whose son , daniel , was killed at columbine , said the tape raises disturbing issues . <SEP>
# | f_prd:  the the the the the , , , , , , . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1040 | time: 9.32 | loss: 6.484
# | tgt:  <GO> likewise , the <NUM>-year bond us30yt = rr slid <NUM> / <NUM> for a yield of <NUM> percent , up from <NUM> percent . <SEP>
# | f_prd:  the the the the the the the the the , , , , , , . . . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the the the the the the the the <NUM> <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1120 | time: 9.38 | loss: 6.536
# | tgt:  <GO> for residents with incomes above $ <NUM> , the income-tax rate will increase to <NUM> percent . <SEP>
# | f_prd:  the the the the the the the the , , , , , , , , , . .
# | b_prd:  the the the the the , , , , , , , , , the <NUM> said . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1200 | time: 9.37 | loss: 6.297
# | tgt:  <GO> florida 's primary isn 't until march <NUM> - following <NUM> other states . <SEP>
# | f_prd:  the the the the , , , , , , , , , , .
# | b_prd:  <GO> <GO> <GO> , , , , , , , , <NUM> <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1280 | time: 9.30 | loss: 6.342
# | tgt:  <GO> in a statement distributed today , <NUM> chechen non-governmental organisations said they would boycott the vote and warned voters to expect fraud . <SEP>
# | f_prd:  the the the the the , , , , , , , , , , . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> the the the , , , , , , , , , , , <NUM> <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1360 | time: 9.31 | loss: 6.301
# | tgt:  <GO> the latest shooting linked to the spree was a november <NUM> shooting at hamilton central elementary school in obetz , about 3km from the freeway . <SEP>
# | f_prd:  the the the the the the the the the the the the , , , , , the the . . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the the the the the the the the the the the the the the the <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1440 | time: 9.34 | loss: 6.102
# | tgt:  <GO> no wonder aol lost <NUM> subscribers last quarter . <SEP>
# | f_prd:  the the the the , , , , , , ,
# | b_prd:  , , , , , , <NUM> <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1520 | time: 9.30 | loss: 5.957
# | tgt:  <GO> a pro-independence radical , miodrag zivkovic , of the liberal alliance , came in second with <NUM> percent of the vote . <SEP>
# | f_prd:  the the the the , , , , , , , , , , , , , . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> the the the , , , , , , , , , , , <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1600 | time: 9.32 | loss: 5.998
# | tgt:  <GO> the redesigned finder also features search , coloured labels for customized organization of documents and projects and dynamic browsing of the network for mac , windows and unix file servers . <SEP>
# | f_prd:  the the the the , , , , , , , , , , , , , , . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the , , , , , , the <NUM> <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1680 | time: 9.30 | loss: 5.874
# | tgt:  <GO> eustachy acknowledged at a news conference wednesday that he was an alcoholic and was seeking treatment . <SEP>
# | f_prd:  the the the the the the the the , , , , , , , , , , ,
# | b_prd:  <GO> <GO> <GO> the the the the the the the , , , , the <NUM> <NUM> . <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP> <SEP>
#
#
# step:  1760 | time: 9.35 | loss: 5.960
# | tgt:  <GO> judge harold baer concluded wednesday that lawyers for the two victims <quote> have shown , albeit barely ... that iraq provided material support to bin laden and al-qaida . <quote> <SEP>
# | f_prd:  the the , , , , , , , , , , . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the , , , , , , , , , , <NUM> <NUM> .
#
#
# step:  1840 | time: 9.39 | loss: 6.002
# | tgt:  <GO> and all of the samples contained molecules that can only be produced when cholesterol interacts with ozone . <SEP>
# | f_prd:  the the , , , , , , , , , , . . .
# | b_prd:  <GO> <GO> <GO> , , , , , , , , , , , , , <NUM> <NUM> .
#
#
# step:  1920 | time: 9.29 | loss: 5.552
# | tgt:  <GO> the document stated : <quote> this report does not attempt to address the complexities of this issue . <quote> <SEP>
# | f_prd:  the the , , , , , , , , , , , , , , . . .
# | b_prd:  <GO> <GO> , , , , , , , , , , , , , , , <NUM> <NUM> .
#
#
# step:  2000 | time: 9.32 | loss: 5.697
# | tgt:  <GO> the council includes <NUM> shiites , five kurds , five sunnis , one christian and one turkoman . <SEP>
# | f_prd:  the the , , , , , , , , , , , , , , . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , the <NUM> .
#
#
# step:  2080 | time: 9.28 | loss: 5.302
# | tgt:  <GO> strikingly , the poll saw very little difference between women and men in their feelings about the former first lady . <SEP>
# | f_prd:  the the the the the the , , , , , , , , , . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> the the the the the the , , , , , , the the <NUM> <NUM> .
#
#
# step:  2160 | time: 9.37 | loss: 5.551
# | tgt:  <GO> <quote> we make no apologies for finding every legal way possible to protect the american public from further terrorist attack , <quote> said barbara comstock , justice department spokeswoman . <SEP>
# | f_prd:  the the , the the the the , , , , , , , , , , . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the the , , , , , , , the <NUM> <NUM> <NUM> .
#
#
# step:  2240 | time: 9.34 | loss: 5.015
# | tgt:  <GO> <quote> about <NUM> percent of the work is already done , <quote> mr. tauzin said . <SEP>
# | f_prd:  the the , the the the , , , , , , , . . . . .
# | b_prd:  <GO> <GO> the the the the , , , , , , , the <NUM> <NUM> .
#
#
# step:  2320 | time: 9.37 | loss: 5.429
# | tgt:  <GO> graham acknowledged that surgery was not exactly the way to begin a campaign , but he said he feels strong and has the go-ahead from his doctors . <SEP>
# | f_prd:  the the , the the the the the , , , , , , , , . . . . .
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the the the , , , , , , , , the <NUM> <NUM> <NUM> .
#
#
# step:  2400 | time: 9.28 | loss: 5.147
# | tgt:  <GO> obus also denied a defense motion to postpone the sept . <NUM> trial date . <SEP>
# | f_prd:  the , the the the the the the , , , , , , . . .
# | b_prd:  the the the , , , , , , , , , the <NUM> <NUM> .
#
#
# step:  2480 | time: 9.38 | loss: 5.052
# | tgt:  <GO> between july <NUM> , <NUM> and june <NUM> , <NUM> , the red cross spent $ <NUM> million on disaster relief , while taking in only $ <NUM> million . <SEP>
# | f_prd:  the the , the the the , , , , , , , , . . . . <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , the <NUM> . .
#
#
# step:  2560 | time: 9.29 | loss: 5.009
# | tgt:  <GO> there are <NUM> u.s. troops in asia , most of them in south korea and japan . <SEP>
# | f_prd:  the , the , the the the the , , , , , , , , , , ,
# | b_prd:  <GO> <GO> , , , , , , , , , , , , , <NUM> said .
#
#
# step:  2640 | time: 9.49 | loss: 5.097
# | tgt:  <GO> <quote> the impact of increased prices has only begun to be seen in the financial numbers of the company , <quote> president and ceo derek pannell said in a statement . <SEP>
# | f_prd:  the the , the the , the , , , , , , , , , , , , , , , . . . . <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , <NUM> <NUM> said .
#
#
# step:  2720 | time: 9.36 | loss: 5.092
# | tgt:  <GO> his decision means that the case against gary lee sampson , including the capital charges against him , will be tried in september . <SEP>
# | f_prd:  the said the , the the , , the , , the the the . . . . <SEP> . <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , , , <NUM> <NUM> <NUM> .
#
#
# step:  2800 | time: 9.28 | loss: 5.024
# | tgt:  <GO> overture 's listings are generated by more than <NUM> advertisers who bid for placement on keywords relevant to their business . <SEP>
# | f_prd:  the the the , , , the , the , , , , the , the , , <SEP> <SEP> <SEP> <SEP>
# | b_prd:  <GO> <GO> the , , , , , , , , , , , , , , the <NUM> <NUM> <NUM> .
#
#
# step:  2880 | time: 9.47 | loss: 5.110
# | tgt:  <GO> a day earlier , a committee appointed by reformist president mohammad khatami called for an independent judicial inquiry into kazemi 's death . <SEP>
# | f_prd:  the the , , the the , , the , the , , , the the , , , the . the . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the , , , , , , , , , <NUM> <NUM> <NUM> <NUM> .
#
#
# step:  2960 | time: 9.34 | loss: 4.997
# | tgt:  <GO> that compared with $ <NUM> million , or <NUM> cents per share , in the year-ago period . <SEP>
# | f_prd:  the the , the <NUM> , , <NUM> <NUM> , , , , <NUM> <NUM> <NUM> . . <SEP>
# | b_prd:  the the , , , , , , , , , , , , the the <NUM> said .
#
#
# step:  3040 | time: 9.48 | loss: 4.749
# | tgt:  <GO> the âµguru microcontroller serves four functions : hardware monitoring , overclocking management , bios update and a troubleshooting-assistance feature called black box . <SEP>
# | f_prd:  the the , , , , , , , , the , , the , , the <NUM> . . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> the the the the , , , , , , , , , , , , the the the said .
#
#
# step:  3120 | time: 9.37 | loss: 4.385
# | tgt:  <GO> williams was white , and four of his victims were black ; the fifth was white . <SEP>
# | f_prd:  the , , the the the , the , , , , the the , , the <SEP>
# | b_prd:  <GO> <GO> the the the , , , , , , , , the the <NUM> . .
#
#
# step:  3200 | time: 9.42 | loss: 4.809
# | tgt:  <GO> united airlines plans to become the first domestic airline to offer e-mail on all its domestic flights by the end of the year , the company announced yesterday . <SEP>
# | f_prd:  the said the , the the the <NUM> the , the , the the , the the . the the . the the . the the . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the the the , , , , , , , , , , the the <NUM> said .
#
#
# step:  3280 | time: 9.36 | loss: 4.517
# | tgt:  <GO> revenue fell to $ 36.9bn from $ 39.3bn a year ago , mainly due to lower vehicle sales . <SEP>
# | f_prd:  the was , <NUM> <NUM> , the <NUM> , <NUM> . . <NUM> . . <NUM> <NUM> . . <SEP>
# | b_prd:  <GO> <GO> the the the the the the , , , , , , , the the the . .
#
#
# step:  3360 | time: 9.40 | loss: 3.758
# | tgt:  <GO> jane doe , deciding to fight the subpoena , asked verizon to withhold her name . <SEP>
# | f_prd:  the said , the , the , the , the to , the . . . <SEP>
# | b_prd:  <GO> the the the the , , , , , , , the the the . .
#
#
# step:  3440 | time: 9.39 | loss: 4.035
# | tgt:  <GO> at best , davydenko 's supporters were naively ignorant to tennis etiquette ; at worst , they cheated â yet went unpenalised by umpire lars graf . <SEP>
# | f_prd:  the the , the , the , , the , the <NUM> , the <NUM> <NUM> the , , the , , , the <NUM> said . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , the the <NUM> said .
#
#
# step:  3520 | time: 9.32 | loss: 4.086
# | tgt:  <GO> massachusetts attorney general tom reilly said he was satisfied with the reimbursement . <SEP>
# | f_prd:  the said , the the , , , the , the <NUM> , <SEP>
# | b_prd:  the the , , , , , , , , the the said .
#
#
# step:  3600 | time: 9.28 | loss: 4.111
# | tgt:  <GO> <quote> it is bad for symbian , <quote> said per lindberg , analyst at dresdner kleinwort wasserstein . <SEP>
# | f_prd:  the the , the to the , the <NUM> <NUM> , , the , the and the . <SEP>
# | b_prd:  <GO> <GO> <GO> the , , , , , , , , , , the the <NUM> said .
#
#
# step:  3680 | time: 9.36 | loss: 3.672
# | tgt:  <GO> the transfers would reduce p & g â s worldwide work force to slightly less than <NUM> , down from <NUM> several years ago . <SEP>
# | f_prd:  the the , , to , the , the <NUM> , , , the , , the . . . the . . . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , , , the the said .
#
#
# step:  3760 | time: 9.35 | loss: 3.863
# | tgt:  <GO> mony shares rose <NUM> per cent to $ <NUM> in after-hours trading in new york . <SEP>
# | f_prd:  the , , <NUM> , to , <NUM> <NUM> . the <NUM> . the <NUM> stock <SEP>
# | b_prd:  <GO> <GO> <GO> , , , , , , , , , the the the said .
#
#
# step:  3840 | time: 9.25 | loss: 3.737
# | tgt:  <GO> the fifth nominee for fiction is scott spencer , for a ship made of paper . <SEP>
# | f_prd:  the the , , the , the the <NUM> <NUM> <NUM> , , the . <SEP>
# | b_prd:  the the , , , , , , , , , , , the the said .
#
#
# step:  3920 | time: 9.32 | loss: 4.057
# | tgt:  <GO> mr annan also warned the us should not use the war on terror as an excuse to suppress <quote> long-cherished freedoms <quote> . <SEP>
# | f_prd:  the the , a to the , , the , the , the and the the , <quote> to the said . <quote> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , the the said .
#
#
# step:  4000 | time: 9.37 | loss: 3.877
# | tgt:  <GO> overall , students are most likely to be taught by a <NUM>-year veteran with a growing workload and slightly eroding interest in staying in teaching , the work-force portrait shows . <SEP>
# | f_prd:  the , the , the the , the the , the <NUM> , , the <NUM> <NUM> , the said the , the . the . the <NUM> . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the , , , , , , , the the said .
#
#
# step:  4080 | time: 9.27 | loss: 3.947
# | tgt:  <GO> convicted child molester brian devries spoke out in response to community outrage wednesday afternoon after registering as a sex offender at the soledad police department . <SEP>
# | f_prd:  the , , the <NUM> was to to the , the . exchange . . the . the <NUM> . . the <NUM> york stock . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , the the the said .
#
#
# step:  4160 | time: 9.28 | loss: 4.050
# | tgt:  <GO> more than <NUM> percent of men on the drug developed high-grade tumors compared with <NUM> percent on placebo . <SEP>
# | f_prd:  the said the , , the , the the of and be to , the . . the . <SEP>
# | b_prd:  <GO> <GO> <GO> the the the , , , , , , , , , the the the said .
#
#
# step:  4240 | time: 9.30 | loss: 4.095
# | tgt:  <GO> ms. gelinas said only <NUM> per cent of those have been fully re-evaluated . <SEP>
# | f_prd:  the was , the <NUM> , be to the and to to . . <SEP>
# | b_prd:  , , , , , , , , , , , the the said .
#
#
# step:  4320 | time: 9.37 | loss: 3.611
# | tgt:  <GO> previously , it had reported a profit of $ <NUM> million , or <NUM> cents a share , for that period . <SEP>
# | f_prd:  the , the , been the the , the <NUM> , , or <NUM> , , the , <quote> the the . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> the the the the the the , , , , , the the the the the <NUM> .
#
#
# step:  4400 | time: 9.35 | loss: 4.130
# | tgt:  <GO> emeryville-based ask jeeves agreed to sell a business software division to a sunnyvale-based rival , kanisa , for $ <NUM> million . <SEP>
# | f_prd:  the shares , the to the to the of , , the the of , the . to the <NUM> . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> the the the , , , , , , , , , , the the the the <NUM> .
#
#
# step:  4480 | time: 9.29 | loss: 3.551
# | tgt:  <GO> treasurys long-range plan is to provide retail buyers of all treasury securities the ability to manage their holdings online in a single account . <SEP>
# | f_prd:  the , the , the the the was , the 's the said the , the said the said . the <NUM> . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the , , , , , , , the the the . .
#
#
# step:  4560 | time: 9.30 | loss: 3.192
# | tgt:  <GO> he blamed guerrillas from the taliban regime ousted in late <NUM> and said it was possible the bomber died in the blast . <SEP>
# | f_prd:  the said , to <NUM> <NUM> time , , the <NUM> , the the said not to the . . the <NUM> . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , the the the . .
#
#
# step:  4640 | time: 9.34 | loss: 3.669
# | tgt:  <GO> the nasdaq composite index increased <NUM> , or <NUM> percent , to <NUM> . <SEP>
# | f_prd:  the technology-laced jones index <NUM> points , or <NUM> percent , to <NUM> . <SEP>
# | b_prd:  the the , , , , , , , , the the the . .
#
#
# step:  4720 | time: 9.32 | loss: 3.558
# | tgt:  <GO> the answer is clearly yes , <quote> said dr. larry norton , deputy physician-in-chief for breast-cancer programs at memorial sloan-kettering cancer center in new york city . <SEP>
# | f_prd:  the broader , the to to the the time time investigation , the united , the , to the the , . the united . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , , , , the the . .
#
#
# step:  4800 | time: 9.26 | loss: 3.209
# | tgt:  <GO> <quote> we 're just dealing with bragging rights here , who wins and who loses . <quote> <SEP>
# | f_prd:  the the think 't know to the enormous , , <quote> said , the and , <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> , , , , , , , , , , the the the said .
#
#
# step:  4880 | time: 9.32 | loss: 3.276
# | tgt:  <GO> though that slower spending made <NUM> look better , many of the expenditures actually will occur in <NUM> . <SEP>
# | f_prd:  the is the said that to to to to be and the <NUM> 's . be . the . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , the the the said .
#
#
# step:  4960 | time: 9.31 | loss: 3.410
# | tgt:  <GO> lt. gov. david dewhurst suggested a political motive for the report , saying : <quote> it sounds like the republican primary started early this year . <quote> <SEP>
# | f_prd:  the the said the , the danish , , the danish , <quote> , <quote> shuttle 's <quote> <NUM> <NUM> market <quote> <quote> to <quote> . <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , the the the <NUM> .
#
#
# step:  5040 | time: 9.28 | loss: 3.527
# | tgt:  <GO> <quote> it remains to be seen whether the revenue recovery will be short- or long-lived , <quote> said james sprayregen , ual bankruptcy attorney , in court . <SEP>
# | f_prd:  the the is , the the , the building , , been a the the , <quote> the the craft . <quote> the <NUM> . . the . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the , , , , , , , , the the the said .
#
#
# step:  5120 | time: 9.29 | loss: 3.569
# | tgt:  <GO> the institute for supply management 's manufacturing index rose to <NUM> in may from <NUM> in april , the biggest monthly gain since december . <SEP>
# | f_prd:  the dow of <NUM> management rr <NUM> index was to <NUM> , the of <NUM> . the . <NUM> the monthly market . the . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , the the the said .
#
#
# step:  5200 | time: 9.32 | loss: 3.653
# | tgt:  <GO> a couple starved their four adopted sons for years while allowing their daughters to feast on takeaways , police and neighbours said today . <SEP>
# | f_prd:  the roman said the the was , , the , the the the said the , the , the said be said . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , the the the said .
#
#
# step:  5280 | time: 9.38 | loss: 3.451
# | tgt:  <GO> the fight over online music sales was disclosed in documents made available monday by the court . <SEP>
# | f_prd:  the company microcontroller online , the 's disclosed by the and and to to the <NUM> of <SEP>
# | b_prd:  <GO> <GO> the the , , , , , , , , , , the the <NUM> .
#
#
# step:  5360 | time: 9.34 | loss: 3.374
# | tgt:  <GO> pdc will also almost certainly fan the flames of speculation about longhorn 's release . <SEP>
# | f_prd:  the , the reshaping have fan the flames of the and the and the and <SEP>
# | b_prd:  the the , , , , , , , , the the the the <NUM> .
#
#
# step:  5440 | time: 9.35 | loss: 2.938
# | tgt:  <GO> mr eddington is to meet union leaders today and tomorrow . <SEP>
# | f_prd:  the howell was <NUM> $ $ of , to $ percent <SEP>
# | b_prd:  , , , , , , , , the the <NUM> .
#
#
# step:  5520 | time: 9.47 | loss: 3.407
# | tgt:  <GO> responding , edward skyler , a spokesman for the mayor , said later : <quote> the comptroller 's statements , while noteworthy for their sensationalism , bear no relation to the facts . <SEP>
# | f_prd:  the 's the minister , the row of the mayor , bear mayor of the group comptroller 's statements , <quote> noteworthy , the sensationalism , <quote> no relation to the facts of <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the , , , , , , , , , the the the the <NUM> .
#
#
# step:  5600 | time: 9.36 | loss: 3.462
# | tgt:  <GO> it also supports coloured labels to better organise documents , and dynamic browsing of the network for mac , windows and unix file servers . <SEP>
# | f_prd:  the said that <quote> dittemore , the said to and the the the , the world , the , the said he self-interest . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> the the the , , , , , , , , , , , the the the the said .
#
#
# step:  5680 | time: 9.25 | loss: 3.582
# | tgt:  <GO> shares of corixa fell <NUM> cents to $ <NUM> on the nasdaq stock market . <SEP>
# | f_prd:  the of the rose <NUM> cents , $ <NUM> percent the new stock exchange . <SEP>
# | b_prd:  , , , , , , , , , , , the the the said .
#
#
# step:  5760 | time: 9.42 | loss: 3.599
# | tgt:  <GO> jon friedman is media editor for cbs.marketwatch.com in new york . <SEP>
# | f_prd:  the of <NUM> <NUM> <NUM> to $ . the new stock <SEP>
# | b_prd:  , , , , , , the the the the said .
#
#
# step:  5840 | time: 9.39 | loss: 3.316
# | tgt:  <GO> oh yeah , miami , boston college and syracuse leaving the big east to take a seat in the atlantic coast conference . <SEP>
# | f_prd:  the brasher , the , the said to syracuse the the the patterson and <quote> the tribe , the clinic country 's . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , the the the said .
#
#
# step:  5920 | time: 9.36 | loss: 3.325
# | tgt:  <GO> but davis adviser roger salazar said the governor 's focus <quote> is on doing the work that he 's being paid to do . <quote> <SEP>
# | f_prd:  the the adviser the technologies said the governor 's focus is said himself the expecting governance , <quote> said the of . <quote> said <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , , , the the said .
#
#
# step:  6000 | time: 9.37 | loss: 3.198
# | tgt:  <GO> rebels sought to consolidate their grip on a troubled northeastern congolese town tuesday after a week of fighting that killed at least <NUM> people . <SEP>
# | f_prd:  the said that he <quote> the , the <quote> time congolese <NUM> , , the way , the , <quote> to the <NUM> , , <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , , the the the said .
#
#
# step:  6080 | time: 9.31 | loss: 3.627
# | tgt:  <GO> the hearing occurred a day after the pentagon for the first time singled out an officer , dallager , for not addressing the scandal . <SEP>
# | f_prd:  the dow was the the 's the crash of the first area , and <NUM> the 's dallager . to the level appearance court . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , the the the the said .
#
#
# step:  6160 | time: 9.29 | loss: 3.222
# | tgt:  <GO> kinsley , for example , wrote in the post monday : <quote> sinners have long cherished the fantasy that william bennett , the virtue magnate , might be among our number . <SEP>
# | f_prd:  the , the contender , the , the roger lawrence , the whose strunk 't the the nomination of <quote> the , the philippine security , and been be the matter . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , the the the the said .
#
#
# step:  6240 | time: 9.35 | loss: 3.116
# | tgt:  <GO> a european union spokesman said the commission was consulting eu member states <quote> with a view to taking appropriate action if necessary <quote> on the matter . <SEP>
# | f_prd:  the architect the 's in the buffer 's consulting eu eu states to to the matter 's <quote> appropriate action unless <quote> appropriate to the matter . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , the the the said .
#
#
# step:  6320 | time: 9.45 | loss: 3.395
# | tgt:  <GO> <quote> i don 't know if the person i 'm talking to now may end up being someone else at another time that may not follow the rules , <quote> parrish said . <SEP>
# | f_prd:  the we 'm quite know the the time 's <quote> talking , <quote> said not to <quote> a occurring , the statement , <quote> said occurring the statement . <quote> said said . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , , the the the said .
#
#
# step:  6400 | time: 9.39 | loss: 3.294
# | tgt:  <GO> they also drafted a non-binding priorities list specifying that a quarter of it may be used to reduce planned <NUM> percent cuts in fees paid to health-care providers . <SEP>
# | f_prd:  the said that he non-binding biology allan , , the company 's the 's be be to the the to . . . the . . be off . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , , the the said .
#
#
# step:  6480 | time: 9.43 | loss: 3.431
# | tgt:  <GO> after posting $ <NUM> million bail , jackson flew to las vegas , where he had been working on a video . <SEP>
# | f_prd:  the the precincts <NUM> million , , was to to the vegas , <quote> the said than than . the challenge . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the , , , , , , , , the the the said .
#
#
# step:  6560 | time: 9.32 | loss: 3.279
# | tgt:  <GO> on aug. <NUM> , juvenile court judge robert yeates ordered that parker be placed in protective custody . <SEP>
# | f_prd:  the the <NUM> , the leaking 's not the totals to be a explode . the . . <SEP>
# | b_prd:  the the , , , , , , , , , , , , the the the said .
#
#
# step:  6640 | time: 9.29 | loss: 3.054
# | tgt:  <GO> doctors would face fines and up to two years in prison for performing the procedure , except as a lifesaving step . <SEP>
# | f_prd:  the 's killed been in was to be vindicated , the , performing the procedure of <quote> to the lifesaving bell . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , the the the said .
#
#
# step:  6720 | time: 9.31 | loss: 3.192
# | tgt:  <GO> i would like to publicly thank sir alex ferguson for making me the player i am today , beckham said in the statement . <SEP>
# | f_prd:  the 's working the congratulate the sir alex ferguson , <quote> the that player library johns aggressive . <quote> said . the sickest . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , the the the said .
#
#
# step:  6800 | time: 9.30 | loss: 3.123
# | tgt:  <GO> some <NUM> million shares have been tendered , oracle said in a statement . <SEP>
# | f_prd:  the knees , , , be tendered in <NUM> said . the new . <SEP>
# | b_prd:  , , , , , , , , , , the the the said .
#
#
# step:  6880 | time: 9.29 | loss: 3.254
# | tgt:  <GO> two of the britons , sandy mitchell from glasgow and glasgow-born william sampson , face the death penalty . <SEP>
# | f_prd:  the far the size , the mitchell , the , be vba sampson , <quote> said young was . <SEP>
# | b_prd:  <GO> <GO> <GO> the the , , , , , , , , , the the the the said .
#
#
# step:  6960 | time: 9.26 | loss: 3.229
# | tgt:  <GO> kinsley , for example , wrote in the post monday : <quote> sinners have long cherished the fantasy that william bennett , the virtue magnate , might be among our number . <SEP>
# | f_prd:  the , the tropical , the , the plane organiser , <quote> sinners said 't cherished the purple of continuously bennett , the united no.3 , and been defeated the region . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , the the the said .
#
#
# step:  7040 | time: 9.40 | loss: 3.364
# | tgt:  <GO> illinois state police accident reconstruction experts were investigating the cause . <SEP>
# | f_prd:  the american items robert pay to to be the <NUM> . <SEP>
# | b_prd:  , , , , , , , the the the said .
#
#
# step:  7120 | time: 9.37 | loss: 3.187
# | tgt:  <GO> the episcopal church , with <NUM> million members , is the u.s. branch of the <NUM> million-member communion . <SEP>
# | f_prd:  the dow church to russia <NUM> million , in was a all-time slice of the <NUM> . year . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> the the the , , , , , , , the the the the said .
#
#
# step:  7200 | time: 9.29 | loss: 3.229
# | tgt:  <GO> <quote> biotech products , if anything , may be safer than conventional products because of all the testing , <quote> said robert fraley , monsanto 's executive vice president . <SEP>
# | f_prd:  the the trading , second-quarter anything , the said safer had conventional target , <quote> a operators defence , <quote> said passenger a. . market-share . a . robert . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the , , , , , , , the the the the <NUM> .
#
#
# step:  7280 | time: 9.29 | loss: 3.227
# | tgt:  <GO> when the manager let him in the apartment , brianna was in her mother 's bedroom lying in a baby 's bathtub , covered with a towel and watching cartoons . <SEP>
# | f_prd:  the the united let him in the apartment , brianna was to the mother and bedroom , , the baby 's bathtub , covered to the towel 's watching cartoons . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , the the the <NUM> .
#
#
# step:  7360 | time: 9.31 | loss: 2.878
# | tgt:  <GO> they also are reshaping the retail business relationship elsewhere , as companies take away ideas and practices that change how they do business in their own firms and with others . <SEP>
# | f_prd:  the said drafted reshaping the retail-business picked relationship leaks , and the than have ideas to practices said he said neighbours can sign . the embassies firms . . the . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , the the the the <NUM> .
#
#
# step:  7440 | time: 9.30 | loss: 3.259
# | tgt:  <GO> rock singer ozzy osbourne , recovering from a quad bike crash , is conscious and joking in his hospital bed , his daughter kelly said tonight . <SEP>
# | f_prd:  the stocks marchant only , the and the interim security angry , is not to <quote> , the family , . a consumption . <quote> the . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , , , , the the said .
#
#
# step:  7520 | time: 9.31 | loss: 2.913
# | tgt:  <GO> andrew m. cuomo and kerry kennedy cuomo plan to divorce . <SEP>
# | f_prd:  the sugden , of assume was to to to <NUM> . <SEP>
# | b_prd:  , , , , , , the the the the said .
#
#
# step:  7600 | time: 9.23 | loss: 2.970
# | tgt:  <GO> shares of the smithfield rose more than <NUM> percent as the company said it expected the transaction to boost earnings immediately . <SEP>
# | f_prd:  the of smithfield smithfield rose $ than <NUM> cents , the new stock in cent to close to boost immediately immediately to <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , the the the said .
#
#
# step:  7680 | time: 9.33 | loss: 2.932
# | tgt:  <GO> <quote> her lawyers are trying to obtain a free pass to download or upload music on-line illegally . <SEP>
# | f_prd:  the the grass are trying to be the free rights and muris , upload huge on-line the . <SEP>
# | b_prd:  <GO> , , , , , , , , , , , , , the the the said .
#
#
# step:  7760 | time: 9.32 | loss: 2.861
# | tgt:  <GO> on saturday , a 149mph serve against agassi equalled rusedski 's world record . <SEP>
# | f_prd:  the the , edt 149mph serve , agassi , rusedski 's the whales to <SEP>
# | b_prd:  the the , , , , , , , the the the the said .
#
#
# step:  7840 | time: 9.33 | loss: 2.615
# | tgt:  <GO> another soldier drowned after diving into an aqueduct in northern iraq , the central command said . <SEP>
# | f_prd:  the dissent winokur to kerry was the aqueduct , the justice . according recordings the said . <SEP>
# | b_prd:  <GO> <GO> <GO> , , , , , , , , , , the the the said .
#
#
# step:  7920 | time: 9.36 | loss: 2.746
# | tgt:  <GO> acting new haven police chief francisco ortiz said police were treating the explosion as a criminal matter . <SEP>
# | f_prd:  the 's shares warn chief francisco ortiz said on restarted treating the explosion of the main matter of <SEP>
# | b_prd:  <GO> , , , , , , , , , , , , , the the the said .
#
#
# step:  8000 | time: 9.40 | loss: 3.007
# | tgt:  <GO> it is a national concern that will touch virtually every american , <quote> abraham said . <SEP>
# | f_prd:  the said the little dittemore in educational be to death cells matter fleet blair said . <SEP>
# | b_prd:  <GO> <GO> the , , , , , , , , , the the the said .
#
#
# step:  8080 | time: 9.33 | loss: 2.969
# | tgt:  <GO> proving that the millville son 's sacrifice would not go unsung , mayor james quinn ordered all city flags flown at half-mast for the next <NUM> days . <SEP>
# | f_prd:  the , the millville son of sacrifice said not go to , the administration quinn is the the and not to half-mast of the <NUM> <NUM> million . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , the the the said .
#
#
# step:  8160 | time: 9.28 | loss: 2.496
# | tgt:  <GO> a european union spokesman said the commission was consulting eu member states <quote> with a view to taking appropriate action if necessary <quote> on the matter . <SEP>
# | f_prd:  the discouraging union man said the commission was consulting eu eu 's to as a view of properly appropriate relation the the struggles to the matter . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the the , , , , , , , , , , , , the the the said .
#
#
# step:  8240 | time: 9.27 | loss: 2.281
# | tgt:  <GO> the male eagle was found by a zookeeper early thursday , suffering from severe puncture wounds in his abdomen . <SEP>
# | f_prd:  the company eagle toll found to the zookeeper of , , including not puncture puncture wounds to the abdomen . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , the the the the said .
#
#
# step:  8320 | time: 9.24 | loss: 2.613
# | tgt:  <GO> statistics from the kansas department of health and environment show that <NUM> abortions were performed in the state last year . <SEP>
# | f_prd:  the , the system , of articular condyle officer and were the , and not . the pacific 's health . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , the the the said .
#
#
# step:  8400 | time: 9.29 | loss: 3.211
# | tgt:  <GO> all three were studied for fingerprints , dna and other traces of evidence , but prosecutors have not yet testified to what , if anything , they yielded . <SEP>
# | f_prd:  the gem , studied to the , dna and the traces of accusing , <quote> he said been pregnancies than to uva the ectopic pregnancies . said yielded . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , , the the the said .
#
#
# step:  8480 | time: 9.33 | loss: 2.676
# | tgt:  <GO> ge stock closed at $ <NUM> a share , down about <NUM> cents , on the new york stock exchange . <SEP>
# | f_prd:  the of closed at $ <NUM> , share , while $ $ percent , at the new york stock exchange . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , , the the the said .
#
#
# step:  8560 | time: 9.50 | loss: 2.886
# | tgt:  <GO> the senate 's proposal will need the support of the democrat-led assembly and pataki to become law . <SEP>
# | f_prd:  the dow newsmagazine dateline music the a lawsuit of the democrat-led assembly , <quote> to be the . <SEP>
# | b_prd:  <GO> <GO> , , , , , , , , , , , , the the the <NUM> .
#
#
# step:  8640 | time: 9.28 | loss: 2.876
# | tgt:  <GO> in nairobi , kenya , the very rev. peter karanja , provost of all saints cathedral , said the u.s. episcopal church <quote> is alienating itself from the anglican communion . <quote> <SEP>
# | f_prd:  the <NUM> , the , the <NUM> dollar peter karanja , provost and terrorism saints cathedral , <quote> the allegations protesting the , <quote> alienating be to the united communion . <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , , the the the said .
#
#
# step:  8720 | time: 9.30 | loss: 2.804
# | tgt:  <GO> an artist who painted a fake <quote> caution low flying planes <quote> sign on a building near ground zero said tuesday that he did not mean to offend anyone . <SEP>
# | f_prd:  the artist who painted that fake jockeys caution low flying planes <quote> the a the building , ground zero , . to practices said be mean . the the . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , , , , the the the said .
#
#
# step:  8800 | time: 9.25 | loss: 2.907
# | tgt:  <GO> the ap quotes a local policeman as saying the british troops were targeted by townspeople angry over civilian deaths during a demonstration yesterday in the town of majar al-kabir . <SEP>
# | f_prd:  the dow of the local disaster unit the that guidance communion east been to townspeople financial vs. runs . and the country of . the associated . majar al-kabir . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , the the the the <NUM> .
#
#
# step:  8880 | time: 9.29 | loss: 2.869
# | tgt:  <GO> in the aftermath of hurricane isabel , federal and local governments remained shut down , as did schools and many businesses . <SEP>
# | f_prd:  the the statement , hurricane isabel , the company cost governments remained be a <NUM> as the pervez to tajikistan pervez . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , , the the the <NUM> .
#
#
# step:  8960 | time: 9.24 | loss: 2.784
# | tgt:  <GO> convicted child molester brian devries spoke out in response to community outrage wednesday afternoon after registering as a sex offender at the soledad police department . <SEP>
# | f_prd:  the , , carlson invividuals was to , prison , martha outrage to of . registering and the half-century offender . the soledad broadcast . . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , , the the the <NUM> .
#
#
# step:  9040 | time: 9.28 | loss: 2.905
# | tgt:  <GO> contrary to what peoplesoft management would have you believe , oracle intends to fully support peoplesoft customers and products for many years to come . <quote> <SEP>
# | f_prd:  the , who jobs was the be replicated a by jobs said to become him to to to name and translator suisse . fischi . <SEP> <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the the the , , , , , , , , , the the the the <NUM> .
#
#
# step:  9120 | time: 9.34 | loss: 2.516
# | tgt:  <GO> the letter stated that a premature stillborn baby was placed on the bed in a blanket . <SEP>
# | f_prd:  the company also that the premature stillborn potter was expected in the united . the phoenix . <SEP>
# | b_prd:  <GO> <GO> the , , , , , , , , , , the the the <NUM> .
#
#
# step:  9200 | time: 9.31 | loss: 2.531
# | tgt:  <GO> mr. parsons has been director of the stennis center , which specializes in rocket engine research and testing , since august . <SEP>
# | f_prd:  the the said been reveal in the stennis straight , <quote> specializes in rocket engine commandments since amrozi , said the of <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , the the the the <NUM> .
#
#
# step:  9280 | time: 9.29 | loss: 2.683
# | tgt:  <GO> the city index outperformed the dow jones industrial average , which rose <NUM> percent during the four-day trading week . <SEP>
# | f_prd:  the dow of outperformed <NUM> dow jones industrial <NUM> / <NUM> rose <NUM> percent , the four-day period yield . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , , the the the said .
#
#
# step:  9360 | time: 9.30 | loss: 3.103
# | tgt:  <GO> trading in loral was halted yesterday ; the shares closed on monday at $ <NUM> . <SEP>
# | f_prd:  the of echostar 's halted <NUM> percent the <NUM>-week closed to the percent the <NUM> . <SEP>
# | b_prd:  the the , , , , , , , , , , the the the said .
#
#
# step:  9440 | time: 9.35 | loss: 3.055
# | tgt:  <GO> the secrecy surrounding terrorist group jemaah islamiyah was again smashed when witnesses from malaysia testified in the treason trial of abu bakar bashir . <SEP>
# | f_prd:  the company vote online nbc jemaah islamiyah , remained in of witnesses , charges , , the treason central , abu bakar bashir . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> the , , , , , , , , , , the the the the said .
#
#
# step:  9520 | time: 9.26 | loss: 2.674
# | tgt:  <GO> tropical storm warnings were in place thursday for jamaica and haiti and watches for the western dominican republic , the southeastern bahamas and the turks and caicos islands . <SEP>
# | f_prd:  the saud experts , signs place , , jamaica and haiti and watches , the western dominican republic , <quote> southeastern bahamas . the turks 's caicos islands . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> <GO> , , , , , , , , , , , , the the the <NUM> .
#
#
# step:  9600 | time: 9.27 | loss: 2.601
# ...
# | b_prd:  , , , , , , , , , , , the the said .
#
#
# step:  9920 | time: 9.29 | loss: 2.543
# | tgt:  <GO> the moment of reckoning has arrived for this west african country founded by freed american slaves in the 19th century . <SEP>
# | f_prd:  the dow of reckoning was true to the competition products role founded . freed angeles slaves . the 19th century . <SEP>
# | b_prd:  <GO> <GO> <GO> <GO> <GO> <GO> the the , , , , , , , , the the the the <NUM> .
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# layers shape= (4, 36, 512)
# [array([[[-5.51728345e-02, -8.03412944e-02,  1.68555409e-01, ...,
#          -1.69505239e-01,  3.87456357e-01,  4.25911754e-01],
#         [-2.79587805e-01, -1.07581295e-01,  2.83621579e-01, ...,
#           7.66544819e-01,  5.55241644e-01, -2.59357542e-01],
#         [-2.31594935e-01,  1.04542053e-03,  7.74892032e-01, ...,
#           4.60583419e-01, -6.60459176e-02, -1.02150060e-01],
#         ...,
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03],
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03],
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03]],
#
#        [[-5.51728345e-02, -8.03412944e-02,  1.68555409e-01, ...,
#          -3.33653212e-01,  2.36370578e-01,  3.96389402e-02],
#         [ 4.30345209e-03,  1.20963909e-01, -5.26957512e-02, ...,
#          -1.60952747e-01, -2.46810347e-01, -8.23024102e-03],
#         [-4.46621239e-01, -4.60462838e-01,  2.95040935e-01, ...,
#           2.06422418e-01,  4.07116786e-02,  7.33675063e-02],
#         ...,
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03],
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03],
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03]],
#
#        [[-5.51728345e-02, -8.03412944e-02,  1.68555409e-01, ...,
#           1.20796762e-01,  2.14361832e-01, -1.04620785e-01],
#         [-1.90584585e-01,  1.78121775e-02, -2.67981887e-01, ...,
#          -8.09706971e-02,  2.34430898e-02,  3.03701520e-01],
#         [ 4.72148687e-01,  7.24685565e-02, -2.76792765e-01, ...,
#          -4.38120365e-02, -1.26584604e-01,  2.14410245e-01],
#         ...,
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03],
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03],
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03]],
#
#        [[-5.51728345e-02, -8.03412944e-02,  1.68555409e-01, ...,
#          -1.14094019e-01,  3.72042321e-02,  2.71705389e-01],
#         [ 4.34674919e-01,  3.55368108e-01,  2.17050612e-01, ...,
#           5.86337820e-02,  2.42369860e-01, -2.66529500e-01],
#         [ 8.93891323e-03,  1.38821527e-01, -9.19613913e-02, ...,
#           2.21108645e-01,  9.17244777e-02, -3.66390467e-01],
#         ...,
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03],
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03],
#         [ 1.98672502e-03, -8.41734931e-04, -1.39328046e-03, ...,
#           1.32044393e-03,  3.07425944e-04, -1.54303294e-03]]],
#       dtype=float32), array([[[ 1.19630724e-01,  1.63943972e-03,  3.93685624e-02, ...,
#          -9.55178857e-01,  9.18429315e-01, -2.91215442e-03],
#         [ 2.88826600e-03,  5.33697486e-01,  2.80075133e-01, ...,
#          -9.61169422e-01,  9.46225047e-01, -2.01307193e-06],
#         [ 6.76976264e-01,  9.43163693e-01,  2.66189128e-01, ...,
#          -9.81736004e-01,  9.51285005e-01, -1.41175615e-05],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 1.19630724e-01,  1.63943972e-03,  3.93685624e-02, ...,
#          -9.84556198e-01,  9.44817126e-01, -3.55115570e-02],
#         [ 1.33666666e-02, -7.12756515e-01,  4.36172262e-02, ...,
#          -9.88845170e-01,  9.56393421e-01, -1.66956428e-03],
#         [ 1.07770026e-01,  3.28672118e-02,  8.00976217e-01, ...,
#          -9.83994603e-01,  9.53592956e-01, -3.49778653e-04],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 1.19630724e-01,  1.63943972e-03,  3.93685624e-02, ...,
#          -9.85341311e-01,  9.60255146e-01, -5.64346738e-05],
#         [ 2.49780552e-03, -7.32735097e-01,  1.53143287e-01, ...,
#          -9.88876402e-01,  9.57570732e-01, -2.89536896e-03],
#         [ 6.33087848e-06, -7.60871947e-01, -2.43052546e-05, ...,
#          -9.94011998e-01,  9.70517159e-01, -7.52627908e-04],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 1.19630724e-01,  1.63943972e-03,  3.93685624e-02, ...,
#          -9.93290901e-01,  9.65856612e-01, -9.07034613e-04],
#         [ 2.61523753e-01,  1.78987421e-02,  3.41718601e-06, ...,
#          -9.91971850e-01,  9.72281277e-01, -7.87125755e-05],
#         [ 1.21450842e-06, -2.82595101e-06,  7.57876560e-02, ...,
#          -9.82164264e-01,  9.50347781e-01, -1.41687560e-04],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#       dtype=float32), array([[[-7.2186047e-01,  7.5582564e-01,  4.3837857e-03, ...,
#           9.9991107e-01, -9.9991369e-01,  9.9912232e-01],
#         [-9.6038002e-01,  8.6818373e-01,  1.4545601e-06, ...,
#           9.9983859e-01, -9.9983633e-01,  9.9887520e-01],
#         [-9.9454355e-01,  9.2612827e-01,  8.2604703e-07, ...,
#           9.9991012e-01, -9.9991417e-01,  9.9919301e-01],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-7.2186047e-01,  7.5582564e-01,  4.3837857e-03, ...,
#           9.9997342e-01, -9.9997687e-01,  9.9947202e-01],
#         [-2.2211376e-08,  3.4346392e-06,  6.8147073e-04, ...,
#           9.9994087e-01, -9.9994433e-01,  9.9930882e-01],
#         [-7.6048946e-01,  9.3397446e-02,  2.1781711e-02, ...,
#           9.9992597e-01, -9.9992883e-01,  9.9925393e-01],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-7.2186047e-01,  7.5582564e-01,  4.3837857e-03, ...,
#           9.9991941e-01, -9.9992359e-01,  9.9922276e-01],
#         [-1.9526672e-02,  2.9738194e-07,  1.3967657e-03, ...,
#           9.9994600e-01, -9.9994957e-01,  9.9933082e-01],
#         [-2.1367606e-08,  5.9320792e-03,  5.1576943e-09, ...,
#           9.9994421e-01, -9.9994659e-01,  9.9932975e-01],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-7.2186047e-01,  7.5582564e-01,  4.3837857e-03, ...,
#           9.9994349e-01, -9.9994659e-01,  9.9932247e-01],
#         [-2.9247101e-06,  2.1837154e-01,  5.7081422e-03, ...,
#           9.9992812e-01, -9.9993110e-01,  9.9924952e-01],
#         [-1.1358041e-03,  3.2354292e-05,  4.2455707e-02, ...,
#           9.9992156e-01, -9.9992526e-01,  9.9923038e-01],
#         ...,
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00, ...,
#           0.0000000e+00,  0.0000000e+00,  0.0000000e+00]]], dtype=float32), array([[[ 4.35386210e-06,  1.62123740e-06, -9.72074195e-05, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         [ 9.63991261e-06,  1.10178895e-07, -7.33348827e-07, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         [ 1.10868086e-05,  4.29293117e-08, -1.87390427e-07, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 4.35386210e-06,  1.62123740e-06, -9.72074195e-05, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         [ 1.01162259e-05,  7.71453679e-01, -9.94366292e-06, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         [ 1.01164642e-05,  9.41842496e-01, -9.04817114e-07, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 4.35386210e-06,  1.62123740e-06, -9.72074195e-05, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         [ 1.21391658e-05,  7.70511806e-01, -5.44177237e-06, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         [ 1.21523090e-05,  9.65126872e-01, -1.19487304e-05, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 4.35386210e-06,  1.62123740e-06, -9.72074195e-05, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         [ 3.99421202e-03,  7.55227923e-01, -2.50379293e-04, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         [ 3.99555312e-03,  9.65427101e-01, -6.73059503e-07, ...,
#           9.99985576e-01, -9.99999404e-01, -1.00000000e+00],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#       dtype=float32), array([[[ 8.98007329e-06, -2.51832651e-04, -4.21296328e-01, ...,
#          -1.37551078e-05,  1.50746109e-05,  8.21313806e-05],
#         [-1.22439997e-06, -3.54930386e-02, -3.87772799e-01, ...,
#          -1.36858653e-05,  1.50768637e-05,  8.25856187e-05],
#         [-3.43476713e-05,  1.19479991e-01, -5.00269294e-01, ...,
#          -1.36180824e-05,  1.50775659e-05,  8.35953542e-05],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 8.98007329e-06, -2.51832651e-04, -4.21296328e-01, ...,
#          -1.25012393e-05,  1.50879296e-05,  9.24117194e-05],
#         [ 3.54621505e-07, -1.02358602e-03, -7.84556448e-01, ...,
#          -1.22820366e-05,  1.50907445e-05,  9.08827933e-05],
#         [ 8.40025223e-08, -1.06006667e-06, -9.87662673e-01, ...,
#          -1.21090625e-05,  1.50938658e-05,  8.93281249e-05],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 8.98007329e-06, -2.51832651e-04, -4.21296328e-01, ...,
#          -1.22820366e-05,  1.50907445e-05,  9.08827933e-05],
#         [ 4.25051034e-08, -8.31750222e-03, -7.60917902e-01, ...,
#          -1.21090625e-05,  1.50938658e-05,  8.93281249e-05],
#         [ 1.61717438e-07, -2.23386669e-05, -8.53216469e-01, ...,
#          -1.19765828e-05,  1.50976266e-05,  8.80575462e-05],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]],
#
#        [[ 8.98007329e-06, -2.51832651e-04, -4.21296328e-01, ...,
#          -1.37551078e-05,  1.50746109e-05,  8.21312715e-05],
#         [ 1.09828397e-05, -6.33945223e-04, -1.15687231e-04, ...,
#          -1.36858653e-05,  1.50768637e-05,  8.25856187e-05],
#         [ 1.84983514e-06, -1.41073189e-08, -2.80315842e-04, ...,
#          -1.36180824e-05,  1.50775659e-05,  8.35953542e-05],
#         ...,
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00]]],
#       dtype=float32)]
